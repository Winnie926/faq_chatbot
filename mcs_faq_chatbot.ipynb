# %% [markdown]
# ## Simple QA Telegram chat bot

# %% [markdown]
# * Author: Boris Ustyugov
# * This is my solution to final assignment for the offline course 'Advanced Data Science with Sberbank'  https://moscoding.ru/sber-data-science/
# * Template code was provided in course materials, lecture 7 https://github.com/gaphex/mcs-nlp/ (Author: Denis Antyuhov)
# * Data was provided by some bank

# %% [markdown]
# ### In this assignment the goal is to process a large corpus of unstructured chat data, discover it's structure and build a Question Answering system based on it

# %%
import numpy as np
import json

import nltk
from gensim.models import Word2Vec
import pymystem3

from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity

# telegram bot 
import logging
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters

# %% [markdown]
# ###  Unzip and explore the data

# %%
# !unzip ./support_logs.zip

# %%
faq = open("./support_faq.txt").read()

# %%
raw_chats = open("./support_chats.txt").read()

# %%
print(faq[:995])
# Out:
# 1 . Могу ли я поменять ПИН-код своей карты <bankname> Банка в банкомате ?
# Да , если банкомат поддерживает данную функцию .
#
# 2 . В каких валютах можно расплачиваться картой <bankname> Банка ?
# Расплачиваться картой и снимать наличные можно в любой валюте .
#
# 3 . При оплате товаров за границей , я оплачиваю НДС в казну другого государства , возможно ли вернуть эти средства ?
# Да , возможно . Для этого вам необходимо в магазине , в котором вы приобретаете товар , попросить предоставить дополнительный чек Tax Free . На данный чек необходимо поставить штамп на таможне . Возврат средств по чекам Tax Free возможен в международном аэропорту ( в стране , где совершалась покупка ) в специальном пункте возврата НДС .
#
# 4 . Безопасно ли направлять ссылку на скачивание выписки на сайте банка ? Может ли другой человек получить мою выписку на сайте банка ?
# Получать выписку по ссылке в письме так же безопасно , как получать выписку в виде вложения - ссылка уникальна и генерируется случайным образом .

# %%
print(raw_chats[:1000])
# Out:
# Chat number = 229391
# Client Id = 4569861
#
# 20:31:24 Клиент : Добрый день ! Могу ли я частично изъять со счета денежные средства ранее 1 месяцев ?
# 20:32:33 Сотрудник : Здравствуйте !
# 20:33:15 Сотрудник : Только полностью закрыть вклад .
# 20:33:34 Клиент : Сколько будет стоить перевод со своей карты в размере 111 т.р . на две карты клиентам <bankname> банк ?
# -- -- -- --
#
# Chat number = 229390
# Client Id = 1522643
#
# 20:30:51 Клиент : Здравствуйте !
# 20:31:38 Клиент : Подскажите , где в онлайн-банке партнерские спецпредложения по картам ?
# 20:32:15 Сотрудник : Здравствуйте !
# 20:32:58 Сотрудник : К сожалению , в новой версии этого раздела еще нет .
# 20:33:20 Клиент : Ясно , будем ждать . Всего доброго !
# 20:33:26 Сотрудник : Всего Вам доброго ! Будут еще вопросы , обращайтесь !
# -- -- -- --
#
# Chat number = 229389
# Client Id = 4680324
#
# 20:30:46 Клиент : Добрый вечер
# 20:31:23 Сотрудник : Здравствуйте !
# 20:32:04 Сотрудник : Чем я могу Вам помочь ?
# 20:32:46 Клиент : У меня была операция по привязке карты к

# %% [markdown]
# ### The data consists of 2 files. The first one contains raw logs of some bank's customer support. The second one contains frequently asked questions with answers.

# %% [markdown]
# ### A good place to start would be to turn the FAQ into a more structured form, then find paraphrases for each question from the chat logs.

# %%
faq_qna = []
buf = []
for line in faq.split("\n"):
    if line == '' and len(buf):
        faq_qna.append(buf)
        buf = []
    else:
        buf.append(line)
        
FAQ = []
for faq_entry in faq_qna:
    faq_dict = {}
    faq_dict['answer'] = faq_entry[1]
    faq_dict['question'] = faq_entry[0]
    faq_dict['paraphrased_questions'] = [faq_entry[0]] ## add paraphrases
    FAQ.append(faq_dict)

# %%
FAQ
# Out:
# [{'answer': 'Да , если банкомат поддерживает данную функцию .',
#   'paraphrased_questions': ['1 . Могу ли я поменять ПИН-код своей карты <bankname> Банка в банкомате ?'],
#   'question': '1 . Могу ли я поменять ПИН-код своей карты <bankname> Банка в банкомате ?'},
#  {'answer': 'Расплачиваться картой и снимать наличные можно в любой валюте .',
#   'paraphrased_questions': ['2 . В каких валютах можно расплачиваться картой <bankname> Банка ?'],
#   'question': '2 . В каких валютах можно расплачиваться картой <bankname> Банка ?'},
#  {'answer': 'Да , возможно . Для этого вам необходимо в магазине , в котором вы приобретаете товар , попросить предоставить дополнительный чек Tax Free . На данный чек необходимо поставить штамп на таможне . Возврат средств по чекам Tax Free возможен в международном аэропорту ( в стране , где совершалась покупка ) в специальном пункте возврата НДС .',
#   'paraphrased_questions': ['3 . При оплате товаров за границей , я оплачиваю НДС в казну другого государства , возможно ли вернуть эти средства ?'],
#   'question': '3 . При оплате товаров за границей , я оплачиваю НДС в казну другого государства , возможно ли вернуть эти средства ?'},
#  {'answer': 'Получать выписку по ссылке в письме так же безопасно , как получать выписку в виде вложения - ссылка уникальна и генерируется случайным образом .',
#   'paraphrased_questions': ['4 . Безопасно ли направлять ссылку на скачивание выписки на сайте банка ? Может ли другой человек получить мою выписку на сайте банка ?'],
#   'question': '4 . Безопасно ли направлять ссылку на скачивание выписки на сайте банка ? Может ли другой человек получить мою выписку на сайте банка ?'},
#  {'answer': 'Подключение к НСПК никак не отразится на клиентском сервисе . Все транзакции по картам обеих платежных систем будут обрабатываться в штатном режиме вне зависимости от банка и стадии его подключения к НСПК',
#   'paraphrased_questions': ['5 . Как повлияет на работу карт подключение МПС Visa и MasterCard к национальной системе платежных карт ?'],
#   'question': '5 . Как повлияет на работу карт подключение МПС Visa и MasterCard к национальной системе платежных карт ?'},
#  {'answer': 'Доступ к системе « Интернет банк » предоставляется только владельцу счета . Небезопасно предоставлять доступ в « Интернет банк » третьим лицам .',
#   'paraphrased_questions': ['6 . У кого есть доступ к системе « Интернет банк » ?'],
#   'question': '6 . У кого есть доступ к системе « Интернет банк » ?'},
#  {'answer': "На начальных этапах обслуживания клиента в банке создаются `` голосовые слепки '' , с которыми сравнивается голос клиента при последующих звонках . При совпадении голосов идентификация происходит в течение нескольких секунд после начала разговора .",
#   'paraphrased_questions': ['7 . Как работает идентификация по голосу ?'],
#   'question': '7 . Как работает идентификация по голосу ?'},
#  {'answer': 'При невозможности идентифицировать клиента по голосу будет произведена полная идентификация .',
#   'paraphrased_questions': ['8 . У меня могут быть сильные помехи на фоне / охрипший голос . Как вы меня идентифицируете по голосу ?'],
#   'question': '8 . У меня могут быть сильные помехи на фоне / охрипший голос . Как вы меня идентифицируете по голосу ?'},
#  {'answer': 'Наш банк внедрил автоматизированную систему идентификации клиента по голосу , которая позволяет частично отказаться от идентификационных вопросов и обработать запрос клиента максимально быстро . Данный способ идентификации также гораздо безопаснее , т.к . у каждого человека голос уникален .',
#   'paraphrased_questions': ['9 . Почему вы перестали спрашивать кодовое слово / стали задавать меньше вопросов при консультировании клиента на линии ?'],
#   'question': '9 . Почему вы перестали спрашивать кодовое слово / стали задавать меньше вопросов при консультировании клиента на линии ?'},
#  {'answer': 'Карту необходимо надрезать вдоль магнитной полосы , при наличии чипа надрезать также его .',
#   'paraphrased_questions': ['10 . Что делать с картой после расторжения договора ?'],
#   'question': '10 . Что делать с картой после расторжения договора ?'},
#  {'answer': 'На текущий момент отвязать карту можно только по звонку в банк , в будущем данная возможность появится в интернет-банке .',
#   'paraphrased_questions': ['11 . Как отвязать привязанную ранее карту ?'],
#   'question': '11 . Как отвязать привязанную ранее карту ?'},
#  {'answer': 'Под привязкой карты подразумевается сохранение данных карты в системах банка для упрощения процедуры пополнения с карты другого банка , в дальнейшем Вам не потребуется повторять реквизиты карты . Привязать к карте <bankname> Банка карту другого банка и осуществить пополнение с нее Вы можете в интернет-банке , мобильном банке , а также по звонку в банк .',
#   'paraphrased_questions': ['12 . Что такое привязка карты ? Как привязать карту и осуществить с нее пополнение ?'],
#   'question': '12 . Что такое привязка карты ? Как привязать карту и осуществить с нее пополнение ?'},
#  {'answer': '<bankname> Банк предоставляет большой выбор способов информирования клиентов об операциях в рамках бесплатных услуг , таких как интернет-банк , мобильный банк , счет-выписки ( SMS , e-mail и Почта РФ ) .',
#   'paraphrased_questions': ['13 . Я слышал , что выходит / вышел закон о бесплатном информировании клиентов со стороны банков об операциях / переводах по карте .'],
#   'question': '13 . Я слышал , что выходит / вышел закон о бесплатном информировании клиентов со стороны банков об операциях / переводах по карте .'},
#  {'answer': 'Почтовые отправления при невозможности их вручения адресатам хранятся в объектах почтовой связи в течение месяца .',
#   'paraphrased_questions': ['17 . В течение какого времени на почте хранятся письма с картами ?'],
#   'question': '17 . В течение какого времени на почте хранятся письма с картами ?'},
#  {'answer': 'Если не получается найти банк по названию , попробуйте произвести поиск по коду федерального агента . Код <bankname> Банка – 168 .',
#   'paraphrased_questions': ['18 . Что делать , если в программе для перевода средств не получается найти <bankname> Банк ?'],
#   'question': '18 . Что делать , если в программе для перевода средств не получается найти <bankname> Банк ?'},
#  {'answer': 'По всем картам нашим банком установлено ограничение на снятие наличных денежных средств - не более 100 000 рублей в сутки .',
#   'paraphrased_questions': ['19 . Существует ли ограничения на снятие наличных денежных средств в банкоматах и ПВН ?'],
#   'question': '19 . Существует ли ограничения на снятие наличных денежных средств в банкоматах и ПВН ?'},
#  {'answer': 'Да , конечно . В рамках данной услуги вы можете получить информацию о состоянии вашего счета через интернет .',
#   'paraphrased_questions': ['20 . Будет ли мне доступна услуга интернет-банк ?'],
#   'question': '20 . Будет ли мне доступна услуга интернет-банк ?'},
#  {'answer': 'Вы можете самостоятельно указать e-mail и подключить данную услугу в интернет-банке , мобильном банке или обратившись в центр обслуживания клиентов банка по телефону .',
#   'paraphrased_questions': ['21 . При оформлении заявки через КЦ / интернет я не указывал e-mail и не получаю счет-выписку по e-mail , что делать ?'],
#   'question': '21 . При оформлении заявки через КЦ / интернет я не указывал e-mail и не получаю счет-выписку по e-mail , что делать ?'},
#  {'answer': 'По дебетовым картам : проценты на сумму пополнения начисляются со дня , следующего за днем поступления данной суммы на счет .',
#   'paraphrased_questions': ['22 . Когда начинают начисляться проценты на доступный остаток по дебетовой карте / перестают начисляться на сумму задолженности по кредитной карте ?'],
#   'question': '22 . Когда начинают начисляться проценты на доступный остаток по дебетовой карте / перестают начисляться на сумму задолженности по кредитной карте ?'},
#  {'answer': 'В каждом ТСП имеются свои инструкции / рекомендации по изъятию карты . Ключевые основания для изъятия карты :',
#   'paraphrased_questions': ['23 . В каких случаях карта может быть изъята сотрудником ТСП ?'],
#   'question': '23 . В каких случаях карта может быть изъята сотрудником ТСП ?'},
#  {'answer': 'В случае отсутствия подписи на оборотной стороне карты в специально отведенном месте , карта считается недействительной , и вам может быть отказано в обслуживании .',
#   'paraphrased_questions': ['24 . Зачем требуется подпись на карте ?'],
#   'question': '24 . Зачем требуется подпись на карте ?'},
#  {'answer': 'Большинство банков используют именно этот способ доставки , как наиболее удобный и безопасный . Ваша карта доставляется вам заказным письмом с объявленной ценностью , которое вы можете получить непосредственно в вашем почтовом отделении . Доставка производится согласно Закону о федеральной Почтовой Службе , по которому почта берет на себя обязательства по доставке . Воспользоваться картой можно только после ее активации , при которой осуществляется идентификация держателя карты .',
#   'paraphrased_questions': ['25 . Безопасно ли доставлять карту по почте ?'],
#   'question': '25 . Безопасно ли доставлять карту по почте ?'},
#  {'answer': 'Карта со статусом « GOLD » / « WORLD » / « Platinum » - это карта более высокого класса , чем « STANDARD » и « ELECTRON » . Премиальные карты пользуются большим доверием у торгово-сервисных предприятий , вероятность отказа в принятии карты со статусом « GOLD » / « WORLD » / « Platinum » к оплате минимальна . Также по картам высокого класса « GOLD » / « WORLD » / « Platinum » можно получать различные скидки в торгово-сервисных предприятиях по всему миру : при оплате картой в ресторанах , магазинах , бутиках , при бронировании отеля , аренде автомобиля .',
#   'paraphrased_questions': ['26 . Что означает статус карты « GOLD » / « WORLD » / « Platinum » ?'],
#   'question': '26 . Что означает статус карты « GOLD » / « WORLD » / « Platinum » ?'},
#  {'answer': 'Да , баланс по карте можно уточнить в банкоматах , обслуживающих карты платежной системы MasterCard / Visa ( в зависимости от платежной системы , которой принадлежит карта ) .',
#   'paraphrased_questions': ['27 . Могу ли я через банкомат узнавать баланс ( доступный остаток ) своей карты ?'],
#   'question': '27 . Могу ли я через банкомат узнавать баланс ( доступный остаток ) своей карты ?'},
#  {'answer': 'Картой можно расплатиться практически в любом ресторане или кафе , во многих супермаркетах и торговых центрах , в других торговых и сервисных компаниях . Сеть приема пластиковых карт постоянно и быстро расширяется .',
#   'paraphrased_questions': ['28 . Где принимают карту ?'],
#   'question': '28 . Где принимают карту ?'},
#  {'answer': 'Да , возможно , причем возможно пополнение не только карты , но и вклада .',
#   'paraphrased_questions': ['29 . Возможно ли погашать задолженность по карте с помощью системы Web-Money и Яндекс.Деньги ?'],
#   'question': '29 . Возможно ли погашать задолженность по карте с помощью системы Web-Money и Яндекс.Деньги ?'},
#  {'answer': 'Можно снимать наличные в любом отделении любого банка , где принимается MasterCard / Visa ( в зависимости от платежной системы , которой принадлежит карта ) . При этом многие банки требуют ввести ПИН-код на терминале .',
#   'paraphrased_questions': ['30 . Возможно ли снять наличные в отделениях банков ?'],
#   'question': '30 . Возможно ли снять наличные в отделениях банков ?'},
#  {'answer': 'Оплата мобильного телефона и коммунальных услуг возможна в банкоматах , в которых настроена данная функция . Тип операции зависит от настроек банкомата , т.е . возможно списание комиссии за совершение операции согласно тарифному плану . Также необходимо учитывать , что банк , которому принадлежит банкомат , может списывать свою комиссию за данную операцию .',
#   'paraphrased_questions': ['31 . Возможна ли оплата мобильного телефона и коммунальных услуг через банкомат ?'],
#   'question': '31 . Возможна ли оплата мобильного телефона и коммунальных услуг через банкомат ?'},
#  {'answer': 'Наш банк выпускает все карты сроком на 5 лет . По истечении данного срока карта будет перевыпущена вам бесплатно .',
#   'paraphrased_questions': ['32 . На какой срок банк выпускает мне карту ?'],
#   'question': '32 . На какой срок банк выпускает мне карту ?'},
#  {'answer': 'С вашими денежными средствами ничего не случится , вам необходимо будет позвонить сразу же в банк , сообщить об утере и заблокировать карту . Банк перевыпустит вам карту и вы сможете продолжать ей пользоваться .',
#   'paraphrased_questions': ['33 . Если я потеряю карту , что будет с деньгами ?'],
#   'question': '33 . Если я потеряю карту , что будет с деньгами ?'},
#  {'answer': 'Вы можете оформить перевод средств на ваш счет в другом банке , средства будут доступны в течение нескольких дней .',
#   'paraphrased_questions': ['34 . Если я потерял карту и еще не восстановил , а мне срочно нужны деньги – что делать ?'],
#   'question': '34 . Если я потерял карту и еще не восстановил , а мне срочно нужны деньги – что делать ?'},
#  {'answer': 'Сумма покупки будет возвращена на счет клиента . В случае кредитной карты : проценты за пользование кредитом будут начислены .',
#   'paraphrased_questions': ['35 . Что произойдет , если оплаченный картой товар будет возвращен в магазин ?'],
#   'question': '35 . Что произойдет , если оплаченный картой товар будет возвращен в магазин ?'},
#  {'answer': 'Для проведения данной операции , пожалуйста , используйте SWIFT код нашего банка : TICSRUMM',
#   'paraphrased_questions': ['36 . Я пытаюсь перевести средства с интернет-сайта на карту вашего банка , но система запросила SWIFT-код . Вы можете его предоставить ?'],
#   'question': '36 . Я пытаюсь перевести средства с интернет-сайта на карту вашего банка , но система запросила SWIFT-код . Вы можете его предоставить ?'},
#  {'answer': 'Наш банк выпускает карты , оснащенные магнитной полосой , данные на которой хранятся в зашифрованном виде , а также карты с магнитной полосой и микрочипом , который обеспечивает дополнительный уровень защиты : подделка чипованной карты практически невозможна . Дополнительную защиту всех карт <bankname> банка при совершении операций в интернете обеспечивает сервис « MasterCard SecureCode » [ МастерКард СекьюрКод ] / « Verified by Visa » [ Верифайд бай Виза ] . При совершении покупок в интернет-магазинах , поддерживающих данную технологию , на мобильный телефон клиента поступает SMS с параметрами покупки и одноразовым кодом для подтверждения операции . Без этих кодов мошенники не смогут совершить покупку .',
#   'paraphrased_questions': ['37 . Какой степенью защиты обладают карты <bankname> Банка ?'],
#   'question': '37 . Какой степенью защиты обладают карты <bankname> Банка ?'},
#  {'answer': 'Да , в написание имени и фамилии на карте можно внести изменения в соответствии с правилами транслитерации . В случае , если фамилия и имя , указанные на карте , отличаются от данных , указанных в загранпаспорте , только по написанию , но не отличаются по звучанию , такая ситуация НЕ может быть причиной отказа в обслуживании карты .',
#   'paraphrased_questions': ['38 . Транслитерация имени на карте не совпадает с транслитерацией имени в загранпаспорте / других документах . Может ли такое различие послужить причиной отказа в обслуживании карты ? Можно ли внести изменения в транслитерацию имени на карте ?'],
#   'question': '38 . Транслитерация имени на карте не совпадает с транслитерацией имени в загранпаспорте / других документах . Может ли такое различие послужить причиной отказа в обслуживании карты ? Можно ли внести изменения в транслитерацию имени на карте ?'},
#  {'answer': 'В банке установлен лимит на максимальное количество операций , совершаемых в сутки - не более 20 операций .',
#   'paraphrased_questions': ['39 . Существуют ли ограничения на количество операций , совершаемых в течение дня / месяца и т.п . ?'],
#   'question': '39 . Существуют ли ограничения на количество операций , совершаемых в течение дня / месяца и т.п . ?'},
#  {'answer': 'При снятии наличных с карты нашего банка вы можете выбрать в меню банкомата любой тип счета , этот параметр не влияет на прохождение операции .',
#   'paraphrased_questions': ['40 . Какой тип счета выбирать при снятии наличных в банкомате ( например : текущий , кредитный , сберегательный ) ?'],
#   'question': '40 . Какой тип счета выбирать при снятии наличных в банкомате ( например : текущий , кредитный , сберегательный ) ?'},
#  {'answer': 'Да , правомерно . Документ , удостоверяющий вашу личность , может потребоваться в целях безопасности в соответствии с правилами , установленными в данном ТСП .',
#   'paraphrased_questions': ['41 . Правомерно ли требование кассира предъявить документ , удостоверяющий личность , при совершении операции в ТСП ?'],
#   'question': '41 . Правомерно ли требование кассира предъявить документ , удостоверяющий личность , при совершении операции в ТСП ?'},
#  {'answer': 'Отличие карты с чипом от обычной карты заключается в том , что при считывании информации используется либо магнитная полоса , либо встроенный в карту микрочип с данными ( в зависимости от возможностей терминала ) . Микрочип обеспечивает дополнительный уровень защиты : подделка чипованной карты практически невозможна .',
#   'paraphrased_questions': ['70 . Чем отличается обычная карта от карты с чипом ?'],
#   'question': '70 . Чем отличается обычная карта от карты с чипом ?'},
#  {'answer': 'Карта с PayPass [ « пэй пас » ] - карта с чипом и технологией бесконтактной оплаты покупок . Для совершения покупки достаточно приблизить карту к специальному терминалу , поддерживающему данную технологию . Это удобно и безопасно .',
#   'paraphrased_questions': ['42 . Что такое карта с PayPass ?'],
#   'question': '42 . Что такое карта с PayPass ?'},
#  {'answer': 'VISA и MasterCard являются наиболее распространенными международными платежными системами , которые предоставляют качественный сервис и безопасность проведения платежей на одинаково высоком уровне .',
#   'paraphrased_questions': ['43 . Какая платежная система лучше VISA или MasterCard ?'],
#   'question': '43 . Какая платежная система лучше VISA или MasterCard ?'},
#  {'answer': 'При совершении операции в интернет-банке , мобильном банке или через центр обслуживания клиентов фактический курс клиент сможет узнать непосредственно перед совершением операции .',
#   'paraphrased_questions': ['44 . По каким курсам осуществляется конвертация валют в <bankname> Банке ?'],
#   'question': '44 . По каким курсам осуществляется конвертация валют в <bankname> Банке ?'},
#  {'answer': 'Если карта перевыпущена по причине окончания срока действия ( пролонгация ) , персонализации или изменения типа карты – номер карты и ПИН–код сохраняются .',
#   'paraphrased_questions': ['45 . Будут ли изменены номер карты и ПИН-код в случае перевыпуска карты ?'],
#   'question': '45 . Будут ли изменены номер карты и ПИН-код в случае перевыпуска карты ?'},
#  {'answer': 'Если ПИН-код был введен неверно 3 раза подряд , возможность совершения любых операций по карте блокируется . Для того , чтобы вы могли воспользоваться данной картой , вам необходимо обратиться в наш банк для разблокировки .',
#   'paraphrased_questions': ['46 . Я неверно ввел ПИН-код 3 раза подряд . Могу ли я после этого совершать покупки в магазинах ( торгово-сервисных предприятиях ) без введения ПИН-кода ?'],
#   'question': '46 . Я неверно ввел ПИН-код 3 раза подряд . Могу ли я после этого совершать покупки в магазинах ( торгово-сервисных предприятиях ) без введения ПИН-кода ?'},
#  {'answer': 'В зависимости от типа карты в приоритете может быть как подпись клиента , так и пин-код .',
#   'paraphrased_questions': ['47 . Почему при оплате в магазине по карте <bankname> Банка требуется / не требуется ввод ПИН-кода .'],
#   'question': '47 . Почему при оплате в магазине по карте <bankname> Банка требуется / не требуется ввод ПИН-кода .'},
#  {'answer': 'Вы можете снимать наличные в любых банкоматах и пунктах выдачи наличных , которые обслуживают карты MasterCard / Visa .',
#   'paraphrased_questions': ['48 . Где я могу снять наличные ?'],
#   'question': '48 . Где я могу снять наличные ?'},
#  {'answer': '<bankname> Банк – надежный банк , успешно работающий во всех регионах России , у нас более 4 миллионов клиентов . Все вклады в нашем банке до 1,4 млн рублей застрахованы государством и вы ничем не рискуете . Вы можете быть уверенными в надежности нашего банка . Дополнительную и детальную информацию о финансовом состоянии нашего банка вы можете узнать в надежных официальных источниках , например , на официальном сайте ЦентроБанка ( www.cbr.ru ) или на нашем официальном сайте www.tinkoff.ru .',
#   'paraphrased_questions': ['49 . Вопросы о надежности <bankname> Банка'],
#   'question': '49 . Вопросы о надежности <bankname> Банка'},
#  {'answer': 'Банк существует с 1994 года . Все это время банк официально зарегистрирован в Центральном Банке РФ , входит в ГОСУДАРСТВЕННУЮ систему страхования , имеет свой регистрационный номер и лицензию . Эту информацию можно увидеть на официальном сайте ЦБ РФ www.cbr.ru . Ранее банк назывался « Химмашбанк » . С января 2007 года название банка было изменено на « <bankname> Кредитные Системы » . Название « <bankname> Банк » используется с января 2015 года , с апреля 2015 года банк официально перешел на новое наименование .',
#   'paraphrased_questions': ['50 . Как давно <bankname> Банк существует на рынке ?'],
#   'question': '50 . Как давно <bankname> Банк существует на рынке ?'},
#  {'answer': 'Единственным акционером ( 100 % уставного капитала банка ) является компания ТиСиЭс Груп Холдинг ПиЭлСи ( TCS GROUP HOLDING PLC ) .',
#   'paraphrased_questions': ['51 . Кто является владельцем банка ?'],
#   'question': '51 . Кто является владельцем банка ?'},
#  {'answer': 'Герб , размещенный на логотипе <bankname> Банка , - герб рода <bankname> , который берет свое начало в XV веке . Род <bankname> внесен в гербовник родовой книги Московской и Орловской губерний .',
#   'paraphrased_questions': ['52 . Что значит год « 1759 » на вашем логотипе ? Логотип напоминает какой-то древний герб – что это за герб , какое он отношение имеет к вам ?'],
#   'question': '52 . Что значит год « 1759 » на вашем логотипе ? Логотип напоминает какой-то древний герб – что это за герб , какое он отношение имеет к вам ?'},
#  {'answer': 'Олег <bankname> – известный предприниматель , основатель компаний « Петросиб » ( сеть магазинов « Техношок » и « МusicШок » ) и « Дарья » ( продукты легкого приготовления ) , компаний <bankname> ( создание сети пивоварен и выпуск пива <bankname> ) .',
#   'paraphrased_questions': ['53 . Кто такой Олег <bankname> ?'],
#   'question': '53 . Кто такой Олег <bankname> ?'},
#  {'answer': 'Лицензия Банка России на право осуществления банковской деятельности № 2673 от 28 января 1994 года была обновлена 24 марта 2015 года в связи с ребрендингом банка . Данная лицензия бессрочная .',
#   'paraphrased_questions': ['54 . Почему информация о дате выдачи лицензии , указанной на сайте ( 28 января 1994 г . ) отличается от даты , указанной непосредственно в документе « Лицензия на осуществление банковских операций » ( 24 марта 2015 г . ) / Какой срок действия данной лицензии ?'],
#   'question': '54 . Почему информация о дате выдачи лицензии , указанной на сайте ( 28 января 1994 г . ) отличается от даты , указанной непосредственно в документе « Лицензия на осуществление банковских операций » ( 24 марта 2015 г . ) / Какой срок действия данной лицензии ?'},
#  {'answer': 'Оливер Хьюз - председатель правления <bankname> Банка . К команде банка присоединился в июне 2007 года . На новом посту О. Хьюз курирует деятельность первого российского банка-монолайнера , специализирующегося на выпуске и обслуживании кредитных карт . До работы в банке возглавлял российское представительство Visa International .',
#   'paraphrased_questions': ['55 . Кто такой Оливер Хьюз ?'],
#   'question': '55 . Кто такой Оливер Хьюз ?'},
#  {'answer': 'На портале www.banki.ru наш банк в течение последних лет занимает первые строчки « Народного рейтинга » банков , создаваемого на основе отзывов посетителей сайта .',
#   'paraphrased_questions': ['56 . Какой рейтинг у вашего банка ? Какое место вы занимаете среди банков ? Другие вопросы про « рейтинг » и т.п .'],
#   'question': '56 . Какой рейтинг у вашего банка ? Какое место вы занимаете среди банков ? Другие вопросы про « рейтинг » и т.п .'},
#  {'answer': 'Вы можете оставить свой отзыв в интернете на сайте банки.ру ( www.banki.ru ) в разделе « Народный рейтинг » или отправить его по Почте России по адресу : 123060 , г. Москва , 1-й Волоколамский проезд , дом 10 , строение 1 , АО <bankname> Банк или на адрес электронной почты : credit @ tinkoff.ru .',
#   'paraphrased_questions': ['57 . Где я могу оставить отзыв о вашем банке / выразить благодарность ?'],
#   'question': '57 . Где я могу оставить отзыв о вашем банке / выразить благодарность ?'},
#  {'answer': 'После расчета на калькуляторе мы часто озвучиваем клиенту процент переплаты , который не совпадает с процентной ставкой , указанной в тарифе .',
#   'paraphrased_questions': ['58 . Почему озвученный сотрудником процент не совпадает с процентом , указанным в тарифе ?'],
#   'question': '58 . Почему озвученный сотрудником процент не совпадает с процентом , указанным в тарифе ?'},
#  {'answer': 'Сумма рекомендуемого платежа указана для вашего удобства , т.к . выплата рекомендуемыми платежами позволит вам платить меньше процентов и быстрее погасить кредит .',
#   'paraphrased_questions': ['59 . Что такое рекомендуемый платеж ? Зачем он указан ?'],
#   'question': '59 . Что такое рекомендуемый платеж ? Зачем он указан ?'},
#  {'answer': 'Первоначально установленный лимит может быть небольшим . Одной из причин может являться отсутствие положительной кредитной истории в нашем банке . Банк регулярно пересматривает кредитные лимиты и увеличивает их тем клиентам , которые активно пользуются картой и вовремя вносят платежи . В случае увеличения лимита мы обязательно проинформируем вас SMS-сообщением .',
#   'paraphrased_questions': ['60 . Почему банк установил мне такой маленький кредитный лимит ?'],
#   'question': '60 . Почему банк установил мне такой маленький кредитный лимит ?'},
#  {'answer': 'К сожалению , информация о причинах отказа не разглашается . Результат рассмотрения заявки зависит от многих факторов , в том числе от наличия или отсутствия кредитной истории . Банк регулярно ( примерно раз в полгода ) пересматривает заявки , по которым ранее было отказано . В случае , если в процессе пересмотра вашей заявки будет принято положительное решение , мы проинформируем вас об этом SMS-сообщением .',
#   'paraphrased_questions': ['61 . По какой причине банк отказал мне в выпуске кредитной карты ?'],
#   'question': '61 . По какой причине банк отказал мне в выпуске кредитной карты ?'},
#  {'answer': 'Операция отмены / возврата средств / компенсации покупок пройдет как пополнение , поэтому минимальный платеж клиента уменьшится на сумму возврата / компенсации или будет полностью погашен .',
#   'paraphrased_questions': ['62 . Как влияют операции отмены / возврата средств / компенсации покупок на минимальный платеж ?'],
#   'question': '62 . Как влияют операции отмены / возврата средств / компенсации покупок на минимальный платеж ?'},
#  {'answer': 'Да , средства будут зачислены на тот номер договора / карты , который был указан при оплате .',
#   'paraphrased_questions': ['63 . Будет ли проведен платеж , если вместо номера кредитного договора / карты был ошибочно введен номер депозитного договора / карты и наоборот ?'],
#   'question': '63 . Будет ли проведен платеж , если вместо номера кредитного договора / карты был ошибочно введен номер депозитного договора / карты и наоборот ?'},
#  {'answer': 'Сообщить клиенту : « Звонки совершаются системой в автоматизированном режиме , поэтому до момента прихода денег в банк эти звонки могут продолжать поступать на ваш телефон . Как только деньги придут , звонки прекратятся » .',
#   'paraphrased_questions': ['64 . Я уже обращался к сотруднику вашего банка и дал обещание оплаты , но мне поступил звонок от автоматизированной системы с напоминанием о необходимости внести платеж для погашения просроченной задолженности .'],
#   'question': '64 . Я уже обращался к сотруднику вашего банка и дал обещание оплаты , но мне поступил звонок от автоматизированной системы с напоминанием о необходимости внести платеж для погашения просроченной задолженности .'},
#  {'answer': 'Означает , что чем больше сумма задолженности , тем меньше в этой сумме доля комиссий и прочих доп . начислений , и , соответственно , меньше полная стоимость кредита .',
#   'paraphrased_questions': ['66 . Что означает последняя фраза « при большем лимите задолженности полная стоимость кредита уменьшается » ?'],
#   'question': '66 . Что означает последняя фраза « при большем лимите задолженности полная стоимость кредита уменьшается » ?'},
#  {'answer': 'Информация по полной стоимости кредита , рассчитанной по требованию законодательства , отражена в заявлении–анкете и индивидуальных условиях . Это только один из вариантов реальных ставок , т.к . по кредитной карте процентных ставок несколько .',
#   'paraphrased_questions': ['67 . Где я могу увидеть информацию по « полной стоимости кредита » ( ПСК ) ?'],
#   'question': '67 . Где я могу увидеть информацию по « полной стоимости кредита » ( ПСК ) ?'},
#  {'answer': 'Указанная в заявлении анкете ставка ( напр. , для ТП 1.0 = 53,30 % годовых ) не учитывает различные варианты погашения кредита , при которых процентная ставка ЗНАЧИТЕЛЬНО ниже . Пример в заявлении-анкете абсолютно не показательный . Требование указывать « полную стоимость кредита » и соответствующие формулы расчетов были разработаны универсальными для всех кредитов – и кредитов на товар , и по картам , но в отличие от кредитов на приобретение товаров , когда имеется фиксированный график платежей и взимания процентов , кредитная карта не предполагает погашение кредита по жесткому графику .',
#   'paraphrased_questions': ['68 . В анкете увидел пункт про « полную стоимость кредита » ( эффективную процентную ставку ) . Что это значит ? Это очень большая « полная стоимость кредита » ( эффективная процентная ставка ) . В других банках – меньше .'],
#   'question': '68 . В анкете увидел пункт про « полную стоимость кредита » ( эффективную процентную ставку ) . Что это значит ? Это очень большая « полная стоимость кредита » ( эффективная процентная ставка ) . В других банках – меньше .'},
#  {'answer': 'При снижении курса валюты страны по отношению к твердым валютам сумма вашего долга / платежа НЕ изменится .',
#   'paraphrased_questions': ['69 . Если произойдет девальвация рубля , изменится ли в связи с этим сумма минимального платежа ?'],
#   'question': '69 . Если произойдет девальвация рубля , изменится ли в связи с этим сумма минимального платежа ?'},
#  {'answer': 'Нет . Если клиент внес платеж , но задолженности по карте нет , то собственные средства остаются на карте клиента и увеличивается доступный остаток . Клиент может использовать средства либо для оплаты покупок , либо произвести снятие наличных , при этом будет взята комиссия за снятие согласно тарифу .',
#   'paraphrased_questions': ['70 . Будет ли возвращена клиенту сумма пополнения , если по карте произвели возврат средств и у клиента образовался положительный баланс ?'],
#   'question': '70 . Будет ли возвращена клиенту сумма пополнения , если по карте произвели возврат средств и у клиента образовался положительный баланс ?'},
#  {'answer': 'E-mail - в течение 3 дней с момента выставления .',
#   'paraphrased_questions': ['71 . Каковы сроки доставки счетов-выписок по почте и на e-mail ?'],
#   'question': '71 . Каковы сроки доставки счетов-выписок по почте и на e-mail ?'},
#  {'answer': 'Да , можно . Для этого вам необходимо обратиться в банк по телефону .',
#   'paraphrased_questions': ['72 . Можно ли будет поменять дату формирования счета-выписки и как это можно сделать ?'],
#   'question': '72 . Можно ли будет поменять дату формирования счета-выписки и как это можно сделать ?'},
#  {'answer': 'Как правило , зачисление платежа через партнеров происходит моментально . В отдельных случаях срок зачисления может составить до 1 рабочего дня .',
#   'paraphrased_questions': ['73 . Как долго идет зачисление средств при оплате ?'],
#   'question': '73 . Как долго идет зачисление средств при оплате ?'},
#  {'answer': 'Да , такая возможность есть . Реквизиты <bankname> Банка можно посмотреть на нашем сайте www.tinkoff.ru , в разделе « Кредитные карты » - « Пополнить карту » . При внесении платежа путем безналичного перечисления может быть начислена комиссия за перевод денежных средств , которую определяет банк , переводящий платеж клиента .',
#   'paraphrased_questions': ['74 . Существует ли возможность погашения задолженности по карте вашего банка со счета в другом банке ? Если да , то какие реквизиты необходимы и как это сделать ?'],
#   'question': '74 . Существует ли возможность погашения задолженности по карте вашего банка со счета в другом банке ? Если да , то какие реквизиты необходимы и как это сделать ?'},
#  {'answer': 'Для операций снятия наличных , а также при невыполнении условий возникновения беспроцентного кредита или начисления базовой процентной ставки на операции покупок , происходит начисление процентов по кредиту по стандартной ставке 0,12 % в день ( ТП 1.0 ) . Проценты начисляются только на сумму реально потраченных средств – то есть , проценты не начисляются на уже начисленные проценты .',
#   'paraphrased_questions': ['75 . Что за процентная ставка , которая начисляется ежедневно ?'],
#   'question': '75 . Что за процентная ставка , которая начисляется ежедневно ?'},
#  {'answer': 'Базовая процентная ставка распространяется только на операции покупок . Ее действие может достигать 60 дней . Она рассчитывается с момента обработки операции покупки до даты формирования Счета-выписки , следующего за счетом-выпиской , где данная операция была отражена .',
#   'paraphrased_questions': ['76 . Что такое базовая процентная ставка ?'],
#   'question': '76 . Что такое базовая процентная ставка ?'},
#  {'answer': 'Беспроцентный период действует только на операции покупок по карте . Чтобы не платить % по покупкам за предыдущий расчетный период , достаточно оплатить в срок полную сумму задолженности , указанную в счете-выписке .',
#   'paraphrased_questions': ['77 . Что такое беспроцентный ( грейс ) период / как удовлетворить условиям беспроцентного ( grace ) периода ?'],
#   'question': '77 . Что такое беспроцентный ( грейс ) период / как удовлетворить условиям беспроцентного ( grace ) периода ?'},
#  {'answer': 'Можно вообще не платить % по операциям покупок по карте , если оплатить полную сумму долга в срок , указанный в выписке . Если условия беспроцентного периода не выполнены , то начисляемые % будут зависеть от срока погашения – чем быстрее вы погасите кредит , тем меньше начислится процентов . В нашем банке нет жесткого графика платежей , единственное условие – оплата ежемесячно не более 8 % от остатка задолженности .',
#   'paraphrased_questions': ['78 . Какие проценты по кредиту по карте ?'],
#   'question': '78 . Какие проценты по кредиту по карте ?'},
#  {'answer': 'Расчетный период – период между датами формирования счетов-выписок , которые формирует банк ( длительность расчетного периода зависит от кол-ва календарных дней между счетами-выписками ) . В счете-выписке отражены все операции по карте за расчетный период , отражена сумма начисленных процентов , сумма минимального платежа , дата до которой необходимо совершить платеж . Дата выставления счета-выписки будет указана в письме , с которым вам будет прислана карта .',
#   'paraphrased_questions': ['79 . Что такое расчетный период ?'],
#   'question': '79 . Что такое расчетный период ?'},
#  {'answer': 'Произвести оплату кредита можно через партнеров <bankname> Банка ( Списки точек оплаты , необходимо смотреть на интрасайте в разделе « Пополнение » ) . При этом комиссия за перевод средств будет равна 0 % . Другую информацию можно увидеть в информационном буклете , выдаваемом вместе с картой или на нашем сайте www.tinkoff.ru в разделе « Кредитные карты » - « Пополнить карту » .',
#   'paraphrased_questions': ['80 . Как платить / где платить по кредиту / по карте ?'],
#   'question': '80 . Как платить / где платить по кредиту / по карте ?'},
#  {'answer': 'Банк обязуется ежемесячно формировать и высылать клиенту счета-выписки по его счету с указанием всей необходимой информации , в т.ч . и даты погашения минимального платежа .',
#   'paraphrased_questions': ['81 . Где указана крайняя дата погашения минимального платежа ? Где написано , что вы даете 25 дней на погашение минимального платежа ?'],
#   'question': '81 . Где указана крайняя дата погашения минимального платежа ? Где написано , что вы даете 25 дней на погашение минимального платежа ?'},
#  {'answer': 'Каждый месяц вам будет приходить счет-выписка , в которой будет указана сумма рекомендуемого и минимального платежа и дата , до которой платеж должен поступить в банк . Обращаем ваше внимание , что после выставления счет-выписки , вы можете внести платеж по карте , не дожидаясь ее доставки . Сумму очередного платежа и дату , до которой платеж должен поступить в банк , вы сможете узнать самостоятельно через автоматизированную систему ( IVR ) , в интернет-банке или центре обслуживания клиентов ( сумма регулярного платежа в ИБ / МБ не отражается ) .',
#   'paraphrased_questions': ['82 . Сколько платить и когда по кредиту по карте ?'],
#   'question': '82 . Сколько платить и когда по кредиту по карте ?'},
#  {'answer': 'Для этого вашему другу достаточно перейти по ссылке , которую вы ему направили . Если вход в форму ввода кредитной заявки происходил по уникальной ссылке , то вместе с заявкой будет передан специальный код , по которому мы сможем определить , что заявка подавалась по вашей рекомендации .',
#   'paraphrased_questions': ['83 . Как моему другу , который оформляет заявку на кредитную карту на сайте вашего банка , сообщить , что он оформляет карту по моей рекомендации ?'],
#   'question': '83 . Как моему другу , который оформляет заявку на кредитную карту на сайте вашего банка , сообщить , что он оформляет карту по моей рекомендации ?'},
#  {'answer': 'Чем большему количеству друзей вы отправите данное предложение , тем больше будет вероятность получения максимальной суммы вознаграждения . Вознаграждение в размере 500 / 1500 рублей начисляется за каждого приглашенного человека , которому выпущена кредитная карта .',
#   'paraphrased_questions': ['84 . Скольким людям я могу порекомендовать оформить карту <bankname> Банка ?'],
#   'question': '84 . Скольким людям я могу порекомендовать оформить карту <bankname> Банка ?'},
#  {'answer': 'В данном поле необходимо указать количество детей до 18 лет .',
#   'paraphrased_questions': ['85 . При указании количества детей в анкете нужно ли учитывать взрослых детей / детей , не вписанных в паспорт ?'],
#   'question': '85 . При указании количества детей в анкете нужно ли учитывать взрослых детей / детей , не вписанных в паспорт ?'},
#  {'answer': 'Вне зависимости от количества оформленных заявок одному клиенту возможно предоставление только ОДНОЙ основной карты .',
#   'paraphrased_questions': ['86 . Если я заполню несколько заявок , я получу несколько карт ?'],
#   'question': '86 . Если я заполню несколько заявок , я получу несколько карт ?'},
#  {'answer': 'Подтверждение мобильного телефона не является обязательным , но мы рекомендуем вам подтвердить номер , т.к . это ускорит процесс рассмотрения вашей заявки .',
#   'paraphrased_questions': ['87 . Обязательно ли подтверждение мобильного телефона после заполнения анкеты ?'],
#   'question': '87 . Обязательно ли подтверждение мобильного телефона после заполнения анкеты ?'},
#  {'answer': 'Обязательными для заполнения являются поля , отмеченные красной звездочкой .',
#   'paraphrased_questions': ['88 . Какие поля при оформлении заявки на сайте являются обязательными для заполнения ?'],
#   'question': '88 . Какие поля при оформлении заявки на сайте являются обязательными для заполнения ?'},
#  {'answer': 'Мы можем назначить встречу с представителем , после чего наш сотрудник самостоятельно доставит в банк необходимый пакет документов .',
#   'paraphrased_questions': ['89 . Доставка пакета документов по почте занимает много времени . Могу ли я самостоятельно приехать в банк для оформления документов ?'],
#   'question': '89 . Доставка пакета документов по почте занимает много времени . Могу ли я самостоятельно приехать в банк для оформления документов ?'},
#  {'answer': 'Тарифный план будет определен на основании вашей кредитной истории . Описание вашего тарифа будет отправлено по почте / доставлено представителем вместе с остальными документами и картой .',
#   'paraphrased_questions': ['90 . Могу ли я где-нибудь ознакомиться с тарифным планом , по которому будет обслуживаться кредитная карта ?'],
#   'question': '90 . Могу ли я где-нибудь ознакомиться с тарифным планом , по которому будет обслуживаться кредитная карта ?'},
#  {'answer': 'При встрече с представителем необходимо иметь при себе только паспорт . Но желательно предоставить и дополнительные документы , такие кк загран паспорт , водительские права , СНИЛС .',
#   'paraphrased_questions': ['91 . Какие документы необходимы при встрече с представителем после оформления заявки на оформление кредитной карты ?'],
#   'question': '91 . Какие документы необходимы при встрече с представителем после оформления заявки на оформление кредитной карты ?'},
#  {'answer': 'На странице используется криптографический протокол передачи данных SSL , поэтому все ваши данные передаются в банк в зашифрованном виде .',
#   'paraphrased_questions': ['92 . Безопасно ли оформление заявки на кредитную карту на сайте , обеспечивается ли защита / шифрование передаваемой информации ?'],
#   'question': '92 . Безопасно ли оформление заявки на кредитную карту на сайте , обеспечивается ли защита / шифрование передаваемой информации ?'},
#  {'answer': 'Нет , клиент должен оформить заявку самостоятельно .',
#   'paraphrased_questions': ['93 . Возможно ли оформление кредитной заявки от имени другого человека ?'],
#   'question': '93 . Возможно ли оформление кредитной заявки от имени другого человека ?'},
#  {'answer': 'Увеличение кредитного лимита осуществляется банком автоматически на основании анализа кредитной истории клиента . Положительные факторы для увеличения лимита формируются при активном использовании карты и своевременном погашении задолженности . Банк НЕ дает гарантий на обязательное увеличение лимита , в случае увеличения клиент обязательно информируется SMS-сообщением . Срок увеличения кредитного лимита индивидуален , может составлять несколько месяцев .',
#   'paraphrased_questions': ['94 . Как я могу повысить свой кредитный лимит ? Могу ли я как-либо инициировать его увеличение ?'],
#   'question': '94 . Как я могу повысить свой кредитный лимит ? Могу ли я как-либо инициировать его увеличение ?'},
#  {'answer': 'Кредитный лимит устанавливается банком на основании информации , которую клиент указывает в заявке на кредитную карту . В дальнейшем кредитный лимит может быть изменен на основании кредитной истории .',
#   'paraphrased_questions': ['95 . На какой кредитный лимит я могу рассчитывать ? Какой максимально возможный / минимальный кредитный лимит карты ?'],
#   'question': '95 . На какой кредитный лимит я могу рассчитывать ? Какой максимально возможный / минимальный кредитный лимит карты ?'},
#  {'answer': 'Наш банк взимает плату за превышение лимита задолженности только в случае превышения более чем на 30 рублей .',
#   'paraphrased_questions': ['96 . Я превысил кредитный лимит . Почему мне не начислили плату за превышение лимита задолженности ?'],
#   'question': '96 . Я превысил кредитный лимит . Почему мне не начислили плату за превышение лимита задолженности ?'},
#  {'answer': 'Это автоматизированные критерии , разработанные с учетом спроса клиентов на подобную услугу , и кредитной политики банка .',
#   'paraphrased_questions': ['97 . На какую сумму максимально я могу превысить лимит ? Какие критерии используются банком для расчета этой суммы ?'],
#   'question': '97 . На какую сумму максимально я могу превысить лимит ? Какие критерии используются банком для расчета этой суммы ?'},
#  {'answer': 'Возможно , вы сейчас совершили попытку на слишком крупную сумму . Одобрены могут быть только операции при относительно небольшом превышении кредитного лимита .',
#   'paraphrased_questions': ['98 . Почему раньше я мог совершать операции с превышением кредитного лимита , а сейчас не могу ?'],
#   'question': '98 . Почему раньше я мог совершать операции с превышением кредитного лимита , а сейчас не могу ?'},
#  {'answer': 'Необходимо просуммировать ежемесячные платежи по всем вашим кредитам и эту сумму указать в анкете в рублях !',
#   'paraphrased_questions': ['99 . Какой ежемесячный платеж по кредитам необходимо указать в анкете ?'],
#   'question': '99 . Какой ежемесячный платеж по кредитам необходимо указать в анкете ?'},
#  {'answer': 'Необходимо указать ваш персональный средний ежемесячный доход , учитывая как официальную зарплату , так и дополнительный доход после налогообложения , т.е . « чистый » . В рублях !',
#   'paraphrased_questions': ['100 . Что указывать в графе « Ваш персональный доход » ?'],
#   'question': '100 . Что указывать в графе « Ваш персональный доход » ?'},
#  {'answer': 'В случае , если у вас нет стационарного телефона , вы можете указать стационарный номер родственников , друзей или знакомых , через которых мы могли бы передавать вам информацию . Рядом со телефоном укажите ФИО контаконтого лица и степень отношения к вам .',
#   'paraphrased_questions': ['101 . У меня нет домашнего номера телефона и нет телефона по фактическому адресу проживания , вы мне откажете в предоставлении кредита ?'],
#   'question': '101 . У меня нет домашнего номера телефона и нет телефона по фактическому адресу проживания , вы мне откажете в предоставлении кредита ?'},
#  {'answer': 'Да , клиент может указать дополнительный личный мобильный телефон при проверке анкеты , но SMS-сообщения будут приходить клиенту на основной телефонный номер , тот , который был указан в анкете .',
#   'paraphrased_questions': ['102 . Может ли клиент указать дополнительный мобильный контактный телефон ?'],
#   'question': '102 . Может ли клиент указать дополнительный мобильный контактный телефон ?'},
#  {'answer': 'Необходимо указать свой действующий номер мобильного телефона . Это нужно для того , чтобы получать на него ежемесячно бесплатные SMS сообщения о состоянии счета , сумму минимального платежа и дату , до которой необходимо совершить платеж .',
#   'paraphrased_questions': ['103 . Какой мобильный телефон вписывать в анкету / указывать в заявке на сайте ?'],
#   'question': '103 . Какой мобильный телефон вписывать в анкету / указывать в заявке на сайте ?'},
#  {'answer': 'Да , можно указать несколько e-mail адресов в поле « Адрес электронной почты ( E-mail ) » , перечислив их через точку с запятой . Счет-выписки будут поступать на все указанные адреса .',
#   'paraphrased_questions': ['104 . Можно ли указать несколько адресов электронной почты для получения банковской информации ? Если да , то где в анкете их можно указать ?'],
#   'question': '104 . Можно ли указать несколько адресов электронной почты для получения банковской информации ? Если да , то где в анкете их можно указать ?'},
#  {'answer': 'Кодовая дата необходима для обслуживания клиентов по телефону через центр обслуживания клиентов .',
#   'paraphrased_questions': ['105 . Что писать в графе « Кодовая дата » ?'],
#   'question': '105 . Что писать в графе « Кодовая дата » ?'},
#  {'answer': 'Кодовое слово необходимо для обслуживания вас через центр обслуживания клиентов по телефону . В качестве кодового слова обычно указывают девичью фамилию матери .',
#   'paraphrased_questions': ['106 . Что писать в графе « Кодовое слово » ?'],
#   'question': '106 . Что писать в графе « Кодовое слово » ?'},
# ...
#   'paraphrased_questions': ['143 . В чем преимущество вкладов в вашем банке , оформленных через Интернет / КЦ ?'],
#   'question': '143 . В чем преимущество вкладов в вашем банке , оформленных через Интернет / КЦ ?'},
#  {'answer': 'На странице используется криптографический протокол передачи данных SSL ( Secure Sockets Layer ) , поэтому все ваши данные передаются в банк в зашифрованном виде .',
#   'paraphrased_questions': ['144 . Безопасно ли оформление заявки на оформление вклада на сайте , обеспечивается ли защита / шифрование передаваемой информации ?'],
#   'question': '144 . Безопасно ли оформление заявки на оформление вклада на сайте , обеспечивается ли защита / шифрование передаваемой информации ?'},
#  {'answer': 'Да , конечно .',
#   'paraphrased_questions': ['145 . У меня есть гражданство РФ , но я редко бываю в России и не имею прописки в городе РФ . Могу ли я открыть вклад в вашем банке ?'],
#   'question': '145 . У меня есть гражданство РФ , но я редко бываю в России и не имею прописки в городе РФ . Могу ли я открыть вклад в вашем банке ?'},
#  {'answer': 'Банк вправе предоставлять имеющуюся информацию о клиенте при возникновении задолженности по счету клиента ( например , в случае технического овердрафта ) .',
#   'paraphrased_questions': ['146 . Я оформляю вклад , а в заявлении сказано , что « Банк вправе предоставлять всю имеющуюся обо мне информацию в объеме и на условиях , определенных Федеральным законом « О Кредитных историях » . Для чего банку моя кредитная история , ведь я открываю вклад ?'],
#   'question': '146 . Я оформляю вклад , а в заявлении сказано , что « Банк вправе предоставлять всю имеющуюся обо мне информацию в объеме и на условиях , определенных Федеральным законом « О Кредитных историях » . Для чего банку моя кредитная история , ведь я открываю вклад ?'},
#  {'answer': 'Если вы уже открыли вклад в нашем банке ( на вкладе есть средства ) , то процентная ставка по вкладу сохранится в течение всего периода действия вклада ( без учета пролонгации ) . Действующие на данный момент ставки для новых вкладов могут быть уменьшены , в том числе по рекомендации центрального банка . Рекомендуем вам оформить вклад в нашем банке уже сейчас , сохранив действующую на данный момент более высокую процентную ставку .',
#   'paraphrased_questions': ['147 . Будут ли меняться процентные ставки по вкладу в сторону уменьшения ? Я видел информацию в интернете , что ваш банк будет снижать процентные ставки по вкладам .'],
#   'question': '147 . Будут ли меняться процентные ставки по вкладу в сторону уменьшения ? Я видел информацию в интернете , что ваш банк будет снижать процентные ставки по вкладам .'},
#  {'answer': 'При встрече с представителем необходимо иметь при себе оригинал паспорта РФ или оригиналы документов , необходимых для открытия вклада иностранным гражданам .',
#   'paraphrased_questions': ['148 . Какие документы необходимы при встрече с представителем после оформления заявки на открытие вклада / карты ?'],
#   'question': '148 . Какие документы необходимы при встрече с представителем после оформления заявки на открытие вклада / карты ?'},
#  {'answer': 'Да , можете . Заявку на открытие вклада можно оформить по звонку в банк или на нашем сайте www.tinkoff.ru .',
#   'paraphrased_questions': ['149 . Могу ли я открыть вклад в долларах / евро ?'],
#   'question': '149 . Могу ли я открыть вклад в долларах / евро ?'},
#  {'answer': 'Мы рекомендуем пополнить вклад как можно раньше с момента подписания договора .',
#   'paraphrased_questions': ['150 . Есть ли ограничения по срокам внесения первоначальной суммы на вклад после подписания договора ?'],
#   'question': '150 . Есть ли ограничения по срокам внесения первоначальной суммы на вклад после подписания договора ?'},
#  {'answer': 'Срок вклада вы указываете при оформлении заявки на сайте / сообщаете сотруднику при оформлении заявки по звонку в банк .',
#   'paraphrased_questions': ['151 . Где я должен указать срок действия моего вклада , если я хочу оформить вклад на 3 , 6 , 12 и т.д . месяцев ?'],
#   'question': '151 . Где я должен указать срок действия моего вклада , если я хочу оформить вклад на 3 , 6 , 12 и т.д . месяцев ?'},
#  {'answer': 'Доставка карты осуществляется представителем вместе с договором и другим комплектом документов в оговоренное с вами время в момент оформления заявки . После оформления заявки ваша карта будет готова уже на следующий день .',
#   'paraphrased_questions': ['152 . Когда я получу карту к вкладу ?'],
#   'question': '152 . Когда я получу карту к вкладу ?'},
#  {'answer': 'Да . Если у вас уже есть расчетная карта , открытая в нашем банке , вы можете открыть новый вклад по звонку в банк , на нашем сайте www.tinkoff.ru , через интернет-банк или мобильное приложение без выпуска новой карты .',
#   'paraphrased_questions': ['153 . Я могу открыть вклад без выпуска пластиковой карты ?'],
#   'question': '153 . Я могу открыть вклад без выпуска пластиковой карты ?'},
#  {'answer': 'Наш представитель доставит вам договор , карту , приветственное письмо , буклет и инструкцию по внесению платежей в заранее оговоренное удобное для вас время .',
#   'paraphrased_questions': ['154 . Каким образом я получу договор ?'],
#   'question': '154 . Каким образом я получу договор ?'},
#  {'answer': 'Процентные ставки действительно высокие , однако , они полностью соответствуют требованиям банка к данному продукту . Благодаря тому , что наш банк работает дистанционно и не содержит сеть отделений , мы можем обеспечить более высокие доходы для наших клиентов за счет отсутствия расходов на содержание и аренду помещений и т.п.. Мы нацелены на долгосрочные отношения с клиентами и стремимся создать все условия для комфортного сотрудничества .',
#   'paraphrased_questions': ['155 . Почему у вас такие высокие проценты ?'],
#   'question': '155 . Почему у вас такие высокие проценты ?'},
#  {'answer': 'Да , будет .',
#   'paraphrased_questions': ['156 . Будет ли мне выплачена компенсация 1,0 % при пополнении вклада путем перевода средств через интернет-банк стороннего банка ?'],
#   'question': '156 . Будет ли мне выплачена компенсация 1,0 % при пополнении вклада путем перевода средств через интернет-банк стороннего банка ?'},
#  {'answer': 'Наш банк признан одним из самых эффективных по показателям получения прибыли на вложенные средства . Мы кредитуем население и вкладываем средства вкладчиков в развитие нашего бизнеса . Банк не занимается размещением средств в других отраслях экономики или спекуляциями на финансовых рынках . Это позволяет постоянно увеличивать прибыль и выплачивать вкладчикам достойные проценты . У нас сотни тысяч довольных клиентов по всей стране , пользующихся кредитными картами . В работе используются самые современные системы , максимальное количество процессов автоматизировано , отсутствуют расходы на сеть отделений . Наши показатели постоянно улучшаются .',
#   'paraphrased_questions': ['157 . Каким образом банк распоряжается средствами , полученными от вкладчиков ? Где банк размещает полученные средства ?'],
#   'question': '157 . Каким образом банк распоряжается средствами , полученными от вкладчиков ? Где банк размещает полученные средства ?'},
#  {'answer': 'Да , перевыпуск карты ко вкладу по истечении срока действия будет бесплатным .',
#   'paraphrased_questions': ['158 . В случае , если я больше никогда не буду открывать вклад , перевыпуск карты ко вкладу по истечении срока действия будет бесплатным ?'],
#   'question': '158 . В случае , если я больше никогда не буду открывать вклад , перевыпуск карты ко вкладу по истечении срока действия будет бесплатным ?'},
#  {'answer': 'Вы можете оставить заявку на закрытие вклада в любое удобное для вас время , но банк рекомендует обращаться заранее за несколько дней , тогда ваш вклад будет закрыт в запланированную дату .',
#   'paraphrased_questions': ['159 . Я планирую закрыть вклад по окончании срока его действия . За сколько дней мне нужно обратиться в Банк для его закрытия или я могу позвонить в день закрытия ?'],
#   'question': '159 . Я планирую закрыть вклад по окончании срока его действия . За сколько дней мне нужно обратиться в Банк для его закрытия или я могу позвонить в день закрытия ?'},
#  {'answer': 'Нашу рекламу можно увидеть в интернете ( баннеры , контекстная реклама , сайт www.tinkoff.ru ) , а также по ТВ .',
#   'paraphrased_questions': ['160 . Где можно увидеть вашу рекламу ?'],
#   'question': '160 . Где можно увидеть вашу рекламу ?'},
#  {'answer': 'Да , это действительно так , для вас нет риска вкладывать деньги в наш банк : у нас привлекательные проценты по вкладам , и , безусловно , сумма до 1,4 млн рублей ( для валютных вкладов рублевый эквивалент данной суммы ) застрахована государством .',
#   'paraphrased_questions': ['161 . Мне известно , что государство страхует вклады вкладчиков на сумму до 1,4 млн рублей , так ли это ?'],
#   'question': '161 . Мне известно , что государство страхует вклады вкладчиков на сумму до 1,4 млн рублей , так ли это ?'},
#  {'answer': 'Да , вы можете оформить заявку на перевод на ваш счет в другом банке или на почтовый перевод обратившись в центр обслуживания клиентов .',
#   'paraphrased_questions': ['162 . Могу ли я изъять вклад , не получив пластиковую карту ?'],
#   'question': '162 . Могу ли я изъять вклад , не получив пластиковую карту ?'},
#  {'answer': 'Мы отвечаем современным требованиям рынка и предлагаем широкий набор продуктов для наших клиентов . Валютные вклады - это распространенный и удобный инструмент для сохранения личных средств . При этом ваши валютные вклады также , как и рублевые защищены системой Государственного страхования вкладов , в которую входит наш банк .',
#   'paraphrased_questions': ['163 . Почему ваш банк начал заниматься валютными депозитами ?'],
#   'question': '163 . Почему ваш банк начал заниматься валютными депозитами ?'},
#  {'answer': 'Эта услуга позволит вам контролировать все расходные операции по карте ( оплата картой ; снятие наличных ; перевод на другие счета ) .',
#   'paraphrased_questions': ['164 . Какая информация будет приходить на мобильный телефон , если я подключу услугу SMS-банк ?'],
#   'question': '164 . Какая информация будет приходить на мобильный телефон , если я подключу услугу SMS-банк ?'},
#  {'answer': 'Кредитные карты : стоимость данной услуги составляется всего 39 или 59 рублей в месяц . Дебетовые карты : cтоимость данной услуги составляет всего 39 рублей в месяц ( 1 USD / 1 EUR для валютных карт ) .',
#   'paraphrased_questions': ['165 . Взимается ли плата за услугу SMS-банк ?'],
#   'question': '165 . Взимается ли плата за услугу SMS-банк ?'},
#  {'answer': 'Система страхования вкладов – государственная структура , основной задачей которой является защита сбережений населения , размещаемых во вкладах и на счетах в российских банках на территории РФ . При наступлении страхового случая в отношении банка - участника системы страхования вкладов - клиентам этого банка государством будут возмещены суммы их вкладов . Максимальная сумма страховой выплаты ( включая проценты ) составляет 1,4 млн . рублей .',
#   'paraphrased_questions': ['166 . Что такое « Система страхования вкладов » ?'],
#   'question': '166 . Что такое « Система страхования вкладов » ?'},
#  {'answer': 'Все причитающиеся проценты по вкладу ( начисленные по день , предшествующий дню отзыва лицензии ) причисляются к основной сумме вклада и включаются в расчет страхового возмещения .',
#   'paraphrased_questions': ['167 . Страхуются ли проценты по вкладу ?'],
#   'question': '167 . Страхуются ли проценты по вкладу ?'},
#  {'answer': 'Да , условия страхования распространяются на любые средства , размещенные физическими лицами в нашем банке , в том числе находящиеся на карте / накопительном счете . Начисленные проценты также застрахованы . Максимальная сумма страховой выплаты на одного клиента составляет 1,4 млн рублей* . Но это не означает потерю денежных средств свыше 1,4 млн рублей , т.к . у нашего банка есть активы , реализуя которые государство будет обязано исполнить все обязательства по выплате денежных средств , независимо от суммы .',
#   'paraphrased_questions': ['168 . Распространяются ли условия страхования на средства , находящиеся на дебетовой карте / накопительном счете ?'],
#   'question': '168 . Распространяются ли условия страхования на средства , находящиеся на дебетовой карте / накопительном счете ?'},
#  {'answer': 'При одобрении кредита наличными банк резервирует для вас кредитную линию . В случае неиспользования кредита наличными в течение 60 календарных дней с момента формирования счета* будет автоматически закрыт , а получение кредита наличными станет недоступно . Договор по продукту кредит наличными вступает в силу после активации продукта ( перевод средств с кредитного договора на дебетовую карту ) .',
#   'paraphrased_questions': ['169 . В течение какого срока после одобрения заявки необходимо активировать « Кредит наличными » ?'],
#   'question': '169 . В течение какого срока после одобрения заявки необходимо активировать « Кредит наличными » ?'},
#  {'answer': 'Проценты на проценты не начисляются . Часть регулярного платежа распределяется на погашение процентов , часть - на погашение основного долга . При внесении платежа , начисленные проценты погашаются в первую очередь .',
#   'paraphrased_questions': ['170 . Начисляются ли проценты на проценты ?'],
#   'question': '170 . Начисляются ли проценты на проценты ?'},
#  {'answer': 'Сумма последнего платежа может быть увеличена за счет процентов , начисленных в период с момента перевода до момента формирования ближайшей выписки по КН . Сумма внесенного регулярного платежа в первую очередь пойдет в счет погашения этих процентов , поэтому в счет погашения основного долга будет распределена несколько меньшая сумма . Таким образом , на момент окончания срока кредита , небольшая часть суммы основного долга останется непогашенной . Этот небольшой остаток основного долга будет приплюсован к сумме последнего платежа .',
#   'paraphrased_questions': ['171 . Может ли платеж за последний месяц отличаться от регулярного ежемесячного платежа ?'],
#   'question': '171 . Может ли платеж за последний месяц отличаться от регулярного ежемесячного платежа ?'},
#  {'answer': 'Нет , комиссия за перевод на дебетовую карту НЕ взимается согласно тарифному плану по КН .',
#   'paraphrased_questions': ['172 . Взимается ли комиссия за выдачу кредита наличными ?'],
#   'question': '172 . Взимается ли комиссия за выдачу кредита наличными ?'},
#  {'answer': 'Услугой можно пользоваться несколько раз . Вы можете подать заявку на новый кредит наличными после погашения задолженности по текущему кредиту .',
#   'paraphrased_questions': ['173 . Сколько раз я могу воспользоваться предложенной услугой « Кредит наличными » ?'],
#   'question': '173 . Сколько раз я могу воспользоваться предложенной услугой « Кредит наличными » ?'},
#  {'answer': 'Заявку на кредит наличными могут подать граждане РФ в возрасте от 18 до 70 лет - для женщин , от 20 до 70 лет - для мужчин , имеющие регистрацию ( постоянную / временную ) на территории РФ .',
#   'paraphrased_questions': ['174 . Кто может воспользоваться услугой « Кредит наличными » ?'],
#   'question': '174 . Кто может воспользоваться услугой « Кредит наличными » ?'},
#  {'answer': 'Банк не может в одностороннем порядке повысить ставки в соответствии со статьей 29 Федерального закона « О банках и банковской деятельности » .',
#   'paraphrased_questions': ['175 . Может ли банк увеличить процентную ставку по кредиту наличными ?'],
#   'question': '175 . Может ли банк увеличить процентную ставку по кредиту наличными ?'},
#  {'answer': '- У Вас будут выгодные условия по тарифу на кредит наличными .',
#   'paraphrased_questions': ['176 . Зачем нужен « Кредит наличными » ?'],
#   'question': '176 . Зачем нужен « Кредит наличными » ?'},
#  {'answer': 'Кредит наличными ( КН ) – это продукт <bankname> Банка - кредит , предоставляемый клиенту за счет перевода средств со специального кредитного счета на дебетовую карту <bankname> Банка .',
#   'paraphrased_questions': ['177 . Что такое кредит наличными ?'],
#   'question': '177 . Что такое кредит наличными ?'}]

# %%
with open('FAQ_PROJECT_DATA.json', 'w') as f:
    json.dump(FAQ, f)

# %% [markdown]
# ### Build  word2vec model from raw chat

# %%
# merge all phrases 
all_texts = [s.split('Клиент :')[1] for s in raw_chats.split('\n') if ('Клиент :' in s)] + [s.split('Сотрудник :')[1] for s in raw_chats.split('\n') if ('Сотрудник :' in s)] + [d['question'] for d in FAQ] + [d['answer'] for d in FAQ]
len(all_texts)
# Out:
# 549509

# %%
def my_tokenizer(text):
    return nltk.regexp_tokenize(text, '\w+')

# %%
# %%time
texts_tokenized = [my_tokenizer(text.lower()) for text in all_texts]
# Out:
# CPU times: user 7.59 s, sys: 225 ms, total: 7.82 s
# Wall time: 7.86 s

# %%
# %%time
w2v_model = Word2Vec(texts_tokenized, size=300, window=5, min_count=5)
# Out:
# CPU times: user 2min 23s, sys: 414 ms, total: 2min 24s
# Wall time: 52 s

# %%
w2v_model.wv.most_similar('банкомат')
# Out:
# [('терминал', 0.7359819412231445),
#  ('банкоматы', 0.6131069660186768),
#  ('кассу', 0.6120798587799072),
#  ('мкб', 0.6066728830337524),
#  ('терминалы', 0.5982102155685425),
#  ('евросеть', 0.5974043011665344),
#  ('систему', 0.5877324342727661),
#  ('сервис', 0.5875207185745239),
#  ('сбербанк', 0.565697431564331),
#  ('сбер', 0.5596617460250854)]

# %% [markdown]
# ### Build  evaluation functions

# %%
def calc_score_for_engine(engine, val_json_path):
    data = []
    with open(val_json_path, 'r') as f:
        for q in json.load(f):
            queries = q['paraphrased_questions']
            answer = q['answer']           
     
            results = [engine.get_top(query, top_k=3) for query in queries]
            for r in results:
                data.append([answer] + r)
            
    ra1 = calc_recall(data, 1)
    ra3 = calc_recall(data, 3)
    print("recall @1: {}\nrecall @3: {}".format(ra1, ra3))
    return ra1, ra3
            
def calc_recall(data, k, bootstrap=0, subsample_rate=None):
    """
    :param data: 2d matrix
    data[i, 0] - true answer, data[i, 1:] - predicted answers, sorted by decreasing score.
    """
    count = np.zeros(1 + bootstrap)
    count_hit = np.zeros(1 + bootstrap)
    for fields in data:
        query = fields[0]

        if subsample_rate is None:
            increment = np.random.poisson(lam=1, size=bootstrap)
        else:
            increment = np.random.binomial(1, subsample_rate, bootstrap)
        increment = np.hstack([[1], increment])

        if query in fields[1:k+1]:
            count_hit += increment
        count += increment

    recall = count_hit / count

    return recall[0]

# %% [markdown]
# ### Build IR engine

# %%
# bag of words encoder
def bow_encoder(wmodel, tokenizer, text, vsize=300):
    """
    This function encodes text into a vector.
    
    First, it tokenizes input text using the provided tokenizer function.
    Then it uses the provided word2vec model to get the vectors corresponding to text's tokens.
    Finally, it computes an average of all token's vectors and returns it.
    
    If the function failed to find and encode any words, it should at least return a vector of zeros.
    """
    tokens = tokenizer(text)
    
    zero_vector = np.zeros(vsize)
    word_vectors = []
    
    for token in tokens:
        if token in wmodel:
            word_vectors.append(wmodel[token])
            
    if len(word_vectors):
        sent_vector = np.mean(word_vectors, axis=0)
    else:
        sent_vector = zero_vector

    return sent_vector

# %%
class ENGINE_3(object):
    def __init__(self, kbase_path, w2v_model):
        with open(kbase_path, 'r') as f:
            self.knowledge_base = json.load(f)
        self.lemmatizer = pymystem3.Mystem()
        self.w2v_model = w2v_model
        
        self.answers = np.array([t['answer'] for t in self.knowledge_base])
        
        self.vectorized_kbase, self.class_indexes = self.vectorize_knowledge_base()
    
    def vectorize(self, data):
        """
        Turns a list of N strings into their vector representation using self.w2v_model.
        In the simplest case, averages the word vectors of all words in a sentence.
        Returns a a matrix of shape [N, 300]
        """
        vectorized = []
        
        for d in data:
            vectorized.append(bow_encoder(self.w2v_model, self.tokenize_and_lemmatize, d))
        
 
        return np.array(vectorized)
        
    def vectorize_knowledge_base(self):
        """
        Vectorizes all questions AND paraphrased questions using the vectorize function.
        Builds a list containing class id (it's index in self.knowledge_base) for each vectorized question.
        
        Example: you vectorized 1 question and 5 paraphrases for that question
        Then you should append the ID of the question to class_labels list 5+1=6 times.
        """
        vectors = []
        class_labels = []
        
        for i , t in enumerate(self.knowledge_base):
            vc = np.vstack([self.vectorize([t['question']]),
                           self.vectorize(t['paraphrased_questions']) ])
            vectors.append(vc)
            class_labels.append(i)
            class_labels += [i]*len(t['paraphrased_questions'])
        
        
        return np.vstack(vectors), class_labels
    
    def compute_class_scores(self, similarities):
        """
        Accepts an array of similarities of shape (self.class_indexes, )
        Computes scores for classes.
        Returns a dictionary of size (n_classes) that looks like
        {
            0: 0.3,
            1: 0.1,
            2: 0.0,
            class_n_id: class_n_score
            ...
        }
        """       
 
        class_scores = dict(zip(range(len(self.answers)), [0]*len(self.answers)))
        for ci, sc in zip(self.class_indexes, similarities):
            class_scores[ci] += sc
        
        return class_scores
        
    def tokenize_and_lemmatize(self, text):
        analysis = self.lemmatizer.analyze(text.strip())
        tokens = []
        for an in analysis:
            if 'analysis' in an:
                try:
                    tokens.append(an['analysis'][0]['lex'])
                except IndexError:
                    tokens.append(an['text'])
        return tokens
    
    def get_top(self, query, top_k=3):
        if isinstance(query, str):
            query = [query]
            
        vectorized_query = self.vectorize(query)
        css = cosine_similarity(vectorized_query, self.vectorized_kbase)[0]
        scores = self.compute_class_scores(css)
        
        sorted_scores = sorted(scores.items(), key= lambda x: x[1])[::-1][:top_k]
        top_classes = np.array([c[0] for c in sorted_scores])
        top_answers = list(self.answers[top_classes])

        return top_answers

# %% [markdown]
# ### Add paraphrases for FAQ from raw chat

# %%
# filter out queries from chat data
chat_queries = [s.split('Клиент :')[1] for s in raw_chats.split('\n') if ('Клиент :' in s)]
chat_queries = [s for s in chat_queries if len(s)>50]
chat_queries = [s for s in chat_queries if s[-1]=='?']
print(len(chat_queries))
# Out:
# 30646

# %%
chat_queries[:10]
# Out:
# [' Добрый день ! Могу ли я частично изъять со счета денежные средства ранее 1 месяцев ?',
#  ' Сколько будет стоить перевод со своей карты в размере 111 т.р . на две карты клиентам <bankname> банк ?',
#  ' Подскажите , где в онлайн-банке партнерские спецпредложения по картам ?',
#  ' Будет ли взыматься комиссия если я переведу другу деньги по номеру его карты , в сторонний банк ?',
#  ' здравствуйте , если я оплачу через приложение коммунальные платежи как мне получить чек , что я оплатила ?',
#  ' У меня при себе нет логина и пароля . я пользуюсь только мобильным приложением . а вы не можете внести эти данные в систему ?',
#  ' здравствуйте , скажите пожалуйста , я случайно перевёл деньги не на тот счет телефона ( оплатил мобильную связь ) можно ли как то вернуть деньги ?',
#  ' Добрый вечер ! Подскажите , действует ли ***** **** при оплате через мобильный банк ?',
#  ' Добрый вечер ! действует ли ***** **** при оплате через мобильный банк ?',
#  ' Каким образом я могу досрочно погасить кредит и как это сделать ?']

# %%
DATA_PATH = './FAQ_PROJECT_DATA.json'

engine = ENGINE_3(DATA_PATH, w2v_model)

# %%
# %%time
# vectorize 
base_queries = [d['question'] for d in FAQ]
base_queries_vec = engine.vectorize(base_queries)
chat_queries_vec = engine.vectorize(chat_queries)
# Out:
# CPU times: user 15.5 s, sys: 1.12 s, total: 16.6 s
# Wall time: 58 s

# %%
# %%time
# fit NearestNeighbors model
NN_model = NearestNeighbors(metric='cosine')
NN_model.fit(chat_queries_vec)
# Out:
# CPU times: user 13 ms, sys: 1 ms, total: 14 ms
# Wall time: 12.8 ms

# %%
# %%time
# add nearest paraphrases from chat queries
K_PARAPH = 5
for i in range(len(FAQ)):
    base_query = base_queries_vec[i,:].reshape((1,-1))
    neigh_ids = list(NN_model.kneighbors(base_query, K_PARAPH, return_distance=False)[0])
    FAQ[i]['paraphrased_questions'] = [chat_queries[i] for i in neigh_ids]
# Out:
# CPU times: user 55.7 s, sys: 5.62 s, total: 1min 1s
# Wall time: 31.1 s

# %%
FAQ
# Out:
# [{'answer': 'Да , если банкомат поддерживает данную функцию .',
#   'paraphrased_questions': [' Хотел узнать , могу ли я сам изменить пин код дебетовой карты , например в банкомате ?',
#    ' Здравствуйте ! Могу ли я установить на свою карту пин код ?',
#    ' Здравствуйте ! Могу ли я установить на свою карту пин код ?',
#    ' могу я изменить пин код на своей карте <bankname> Блэк ?',
#    ' Добрый вечер , могу ли я поменять пин код в онлайн банке ?'],
#   'question': '1 . Могу ли я поменять ПИН-код своей карты <bankname> Банка в банкомате ?'},
#  {'answer': 'Расплачиваться картой и снимать наличные можно в любой валюте .',
#   'paraphrased_questions': [' Здравствуйте ! Какие дебетовые карты можно открыть в валюте ? Только T****** B**** ?',
#    ' где в клиент банке под андроид можно открыть виртуальную карту ?',
#    ' Ясно . Каким образом в дальнейшем можно обналичить валютную карту ?',
#    ' Можно ли держателю дополнительной карте обеспечить доступ в интернет-банк и мобильный банк ?',
#    ' И какую максимальную сумму можно перевести с карты другого банка ?'],
#   'question': '2 . В каких валютах можно расплачиваться картой <bankname> Банка ?'},
#  {'answer': 'Да , возможно . Для этого вам необходимо в магазине , в котором вы приобретаете товар , попросить предоставить дополнительный чек Tax Free . На данный чек необходимо поставить штамп на таможне . Возврат средств по чекам Tax Free возможен в международном аэропорту ( в стране , где совершалась покупка ) в специальном пункте возврата НДС .',
#   'paraphrased_questions': [" На странице ***** : //***.******* . **/******/*****/***********/ чётко указано , что начисляется `` 1 % при покупке авиабилетов в любых других компаниях '' . У меня имеются документы подтверждающие факт оплаты авиабилета в данном ТСП . Влиять на MCC я не могу . Что в таком случае делать ?",
#    ' я получаю 11 % милями даже в случае оплаты в отеле а не сразу при бронировании ?',
#    ' Я больше пополнять не собираюсь . Я положила деньги , чтобы картой рассчитываться при покупках . Комиссия будет ещё какая то при оплатах в магазинах , кафе и прочих ?',
#    ' Оплата производилась от моего лица , но платила я за другого человека . Каким образом в ГИБДД поймут за какой именно штраф уплачены деньги ?',
#    ' Здравствуйте . Мне нужно оплатить госпошлину за приглашение на въезд в Россию иностранного гражданина . Какой платеж в организацию мне выбрать - В бюджетные организации или Оплата налогов и сборов ?'],
#   'question': '3 . При оплате товаров за границей , я оплачиваю НДС в казну другого государства , возможно ли вернуть эти средства ?'},
#  {'answer': 'Получать выписку по ссылке в письме так же безопасно , как получать выписку в виде вложения - ссылка уникальна и генерируется случайным образом .',
#   'paraphrased_questions': [' Может ли банк прислать на е-мейл подтверждение транзакций за 1 апреля ?',
#    ' Здравствуйте ! Могу ли я рассчитывать на ипотеку в Вашем банке ?',
#    ' Здравствуйте ! На каких условиях банк предоставляет ипотеку ?',
#    ' Как перевести рубли на карту украинского привет банка ? Если это возможно , то на каких условиях ?',
#    ' Только на снятие ? На перевод на другую карту стороннего банка под средством мобильного предложения , так возможно ?'],
#   'question': '4 . Безопасно ли направлять ссылку на скачивание выписки на сайте банка ? Может ли другой человек получить мою выписку на сайте банка ?'},
#  {'answer': 'Подключение к НСПК никак не отразится на клиентском сервисе . Все транзакции по картам обеих платежных систем будут обрабатываться в штатном режиме вне зависимости от банка и стадии его подключения к НСПК',
#   'paraphrased_questions': [' Здравствуйте ! Хочу к карте <bankname> Платинум привязать карту другого банка . Как это сделать ?',
#    ' Здравствуйте ! Как оставить заявку на продление карты ?',
#    ' Система по карте не может свою же карту распознать ?',
#    ' Здравствуйте ! скажите , пожалуйста , можно ли выпустить дополнительную дебетовую карту ( к уже имеющемуся счёту ) другой платёжной системы ( отличающейся от платёжной системы основной карты ) ?',
#    ' Подскажите , как отправить заявку на выпуск валютных карт ?'],
#   'question': '5 . Как повлияет на работу карт подключение МПС Visa и MasterCard к национальной системе платежных карт ?'},
#  {'answer': 'Доступ к системе « Интернет банк » предоставляется только владельцу счета . Небезопасно предоставлять доступ в « Интернет банк » третьим лицам .',
#   'paraphrased_questions': [' у меня как у клиента банка есть льготы по страхованию ?',
#    ' Отлично . Правильно ли я понимаю , что у абонента , для которого будет выпущена доп . карта , будут свои логин и пароль , а также подтверждение операций по доп . карте ( включая смс-информирование ) будет привязано к его номеру телефона , но личный кабинет у нас будет один ?',
#    ' есть ли какие-нибудь преимущества по отношению к кредиткам других банков ?',
#    ' ******* ****** * 1 поддерживает оплату , но у других банков . будет ли данная возможность реализылана у <bankname> банка ?',
#    ' у банка <bankname> +1 111 11 11 11 есть такой номер ?'],
#   'question': '6 . У кого есть доступ к системе « Интернет банк » ?'},
#  {'answer': "На начальных этапах обслуживания клиента в банке создаются `` голосовые слепки '' , с которыми сравнивается голос клиента при последующих звонках . При совпадении голосов идентификация происходит в течение нескольких секунд после начала разговора .",
#   'paraphrased_questions': [' по валютной карте дебетовой такие же условия как по рублевой ?',
#    ' как это узнать . И как узнать список партнеров по которым начисляются баллы ?',
#    ' Здравствуйте , как распечатать чек по ранее осуществленной транзакции ?',
#    ' Здравствуйте хотел уточнить по спецпредложению 11 % скидка в пекарне P*** - как это работает ?',
#    ' Здравствуйте . Как мне получить расшифровку по кэш бэку ?'],
#   'question': '7 . Как работает идентификация по голосу ?'},
#  {'answer': 'При невозможности идентифицировать клиента по голосу будет произведена полная идентификация .',
#   'paraphrased_questions': [' это я помню . ) у вас есть возможность увидеть , сколько я буду должна на 1 апреля ?',
#    ' У меня на счету было 11111 сейчас 11111 вы говорите что ничего не взымается ?',
#    ' Здравствуйте . У вас была акция по V**** . Я совершил покупку у них на сайте и ничего не произошло и сама акция пропала . Как это ?',
#    ' Здравствуйте ! У меня по карте сегодня была выписка . Поясните пожалуйста : у меня кэшбэк по транспорту-1 % , я купил билетов на 11 111 , а начислено всего 111 руб , где я ошибся ?',
#    ' Доброе утро . У меня вопрос по начислению баллов и акциям по спецпредложениям . У меня есть спецпредложение от вкусвилл - 11 % на первую покупку . Также у меня есть транзакция в их магазине примерно на 1111 ( пару недель назад ) . Но мне пишут , что предложение еще не активировано . Как такое может быть ?'],
#   'question': '8 . У меня могут быть сильные помехи на фоне / охрипший голос . Как вы меня идентифицируете по голосу ?'},
#  {'answer': 'Наш банк внедрил автоматизированную систему идентификации клиента по голосу , которая позволяет частично отказаться от идентификационных вопросов и обработать запрос клиента максимально быстро . Данный способ идентификации также гораздо безопаснее , т.к . у каждого человека голос уникален .',
#   'paraphrased_questions': [' не поняла вопроса : а что Вы выбираете при переводе ?',
#    ' вы мне можете ответить ? как получается при расходе 111111 кэшбэк 1111 ?',
#    ' Еще вопрос - правда , что при обмене более 11111 валюты спрэд на 11-11 копеек меньше ?',
#    ' Вы не ответили на вопрос выше . Индивидуален- да . Узнать его можно ?',
#    ' Вопрос : почему прошло списание 11 рублей при наличии на карте денежных средств свыше 11111 рублей ?'],
#   'question': '9 . Почему вы перестали спрашивать кодовое слово / стали задавать меньше вопросов при консультировании клиента на линии ?'},
#  {'answer': 'Карту необходимо надрезать вдоль магнитной полосы , при наличии чипа надрезать также его .',
#   'paraphrased_questions': [' Я получу какое-то уведомление об этом ? Как поступить с картой после расторжения договора ?',
#    ' И МОЖНО ЗАКАЗАТЬ ВЫПИСКУ ПОСЛЕ ЗАКРЫТИЯ КАРТЫ , ДОГОВОРА , ЧТО БАНКУ НЕ ДОЛЖЕН ?',
#    ' скажите суммы для закрытия договора и блокировки карты сегодня , хватает денежных средств ?',
#    ' здравствйте ! я пытаюсь пополнить карту с кариты другого банка , а приложение говорит , что срок карты истек . хотя та карта с которой хочу пополнить действительна до 11 апреля . что делать ?',
#    ' Здравствуйте ! Я новый клиент , пытаюсь пополнить счёт с карты втб , почему то операцию отклоняют и <bankname> тоже блокирует возможность пополнения после неудачных попыток , что делать ?'],
#   'question': '10 . Что делать с картой после расторжения договора ?'},
#  {'answer': 'На текущий момент отвязать карту можно только по звонку в банк , в будущем данная возможность появится в интернет-банке .',
#   'paraphrased_questions': [' Здравствуйте , подскажите как закрыть кредитную карту ?',
#    ' Здравствуйте подскажите как активировать кредитную карту ?',
#    ' Здравствуйте , я забыл пинкод карты , как востановить ?',
#    ' здравствуйте ! хочу заблокировать карту , как это заделать ?',
#    ' Здравствуйте ! Как оставить заявку на продление карты ?'],
#   'question': '11 . Как отвязать привязанную ранее карту ?'},
#  {'answer': 'Под привязкой карты подразумевается сохранение данных карты в системах банка для упрощения процедуры пополнения с карты другого банка , в дальнейшем Вам не потребуется повторять реквизиты карты . Привязать к карте <bankname> Банка карту другого банка и осуществить пополнение с нее Вы можете в интернет-банке , мобильном банке , а также по звонку в банк .',
#   'paraphrased_questions': [' А мне как им проблему обозначить ? Что не работает перевод с карты на карту ?',
#    ' Почему не получается пополнить карту <bankname> с карты втб ?',
#    ' Здрасте . Почему не могу пополнить карту с карты сбербанка ?',
#    ' Понятно , а как это реализовать ? Выбрать перевод с карты на карту ?',
#    ' Увы проблема не решилась . У меня карта <bankname> блэк , дебетовая . Карта прекрасно платит через *** . Я хочу платить не картой , а андроид-смартфоном с *** . как это делается в нфс-кошельке <bankname> . это возможно с картой блэк , а не с кошельком ?'],
#   'question': '12 . Что такое привязка карты ? Как привязать карту и осуществить с нее пополнение ?'},
#  {'answer': '<bankname> Банк предоставляет большой выбор способов информирования клиентов об операциях в рамках бесплатных услуг , таких как интернет-банк , мобильный банк , счет-выписки ( SMS , e-mail и Почта РФ ) .',
#   'paraphrased_questions': [' А разве банк не обязан бесплатно информировать клиента о совершенных им расходных операциях по карте ?',
#    " `` По покупкам по карте Вы можете заказывать в банке справки об операциях . '' - подскажите как это делается ?",
#    ' Здравствуйте ! Когда я заказывала кредитную карту , оператор кол-центра сообщила , что решение о размере кредита принимает сотрудник банка при выдаче карты и сумма кредита составляет от 11111 руб . Получается представитель вашего банка , выдававший мне карту , обманул меня , сказав , что решение о лимите моей карты 11111 руб принято в головном офисе ?',
#    ' У меня списали средства с карты 11 марта 11111,11 рублей мошенники , заявление в полицию есть , талон о заведении уголовного дела я вашему банку отсылала ранее . Мне для следователя нужна выписка с печатью банка и подписью о факте списания . Как это сделать ?',
#    ' Спасибо ! еще была новость о том что перевод ****1**** с карты <bankname> на карту другого банка тоже без комиссии . подскажите по лимитам в этом вопросе ?'],
#   'question': '13 . Я слышал , что выходит / вышел закон о бесплатном информировании клиентов со стороны банков об операциях / переводах по карте .'},
#  {'answer': 'Почтовые отправления при невозможности их вручения адресатам хранятся в объектах почтовой связи в течение месяца .',
#   'paraphrased_questions': [' в течении какого времени деньги поступят на карту сбербанка ?',
#    ' Здравствуйте . Подскажите , в течение какого времени производится возврат средств на карту ( возврат производился на АЗС ) ? ?',
#    ' Скажите пожалуйста в течении какого времени осуществляется перевод денежных средств с карты на карту ?',
#    ' В течении какого времени операция подтвердиться с вашей стороны ?',
#    ' Здравствуйте , я перекидывала денежные средства с карты на карту ! В течении какого времени деньги будут зачислены ?'],
#   'question': '17 . В течение какого времени на почте хранятся письма с картами ?'},
#  {'answer': 'Если не получается найти банк по названию , попробуйте произвести поиск по коду федерального агента . Код <bankname> Банка – 168 .',
#   'paraphrased_questions': [" Добрый день ! Мне необходимо сделать валютный свифт перевод в адрес организации , для оплаты виллы для летнего отдыха . Сегодня попытался сделать перевод , получил смску `` отказ . документ в интернет-банке загружен не полностью '' . Что это значит и что делать для успешной отправки сего перевода ?",
#    ' А в каком случае банк <bankname> начисляет дополнительный 1 % , когда я делаю перевод с карты Сбербанка на карту <bankname> или если я перевод из Сбербанка делаю по реквизитам ?',
#    ' Здравствуйте Слышал , не вдаваясь в детали , что теперь возможен перевод на карту другого банка без комиссии . Однако в приложении обещается комиссия . Чего я не учёл ?',
#    ' Вот вы написали что нужно обратиться в банк для уточнения статуса перевода в тенькофф банк или в тот на который я делал перевод ?',
#    ' не могу с дебетовую карты перевести дс на карту другого банка в размере 1111 р. пишет что недостаточно дс . комиссия как я понимаю отсутсвует за перевод . не подскажите в чем дело ?'],
#   'question': '18 . Что делать , если в программе для перевода средств не получается найти <bankname> Банк ?'},
#  {'answer': 'По всем картам нашим банком установлено ограничение на снятие наличных денежных средств - не более 100 000 рублей в сутки .',
#   'paraphrased_questions': [' Здравствуйте.Есть ли какие то ограничения на снятие наличных в день ?',
#    ' здравствуйте ! планирую использовать дебетовую карту в евро для снятия наличных на Кипре , Айя-Напа . Как я могу узнать будет ли в местных банкоматах комиссия за снятие или нет ?',
#    ' Подскажите какие лимиты на снятие наличных в банкомате Райфайзен и Альфа-банк ?',
#    ' добрый вечер . хочу открыть дебетовую долларовую карту для использования зарубежом . преимущественно в сша . расскажите пожалуйста смогу ли я снимать наличные без комиссии и в каких банкоматах ? какие ограничения на пополнения и снятия ?',
#    ' Есть ли лимиты на картах P******* по снятию наличных в ₽ и в $ ?'],
#   'question': '19 . Существует ли ограничения на снятие наличных денежных средств в банкоматах и ПВН ?'},
#  {'answer': 'Да , конечно . В рамках данной услуги вы можете получить информацию о состоянии вашего счета через интернет .',
#   'paraphrased_questions': [' Есть ли где возможность посмотреть в интернет банке за что у меня было списаны балы ?',
#    ' Здравствуйте ! Хотелось бы уточнить . 11 марта с меня списали 11 р за СМС банк . Хотя при обращении в банк месяцем ранее мне эту услугу должны были отключить . В итоге мною СМС банк была вручную отключена через интернет-банк . Как так получилось , что СМС банк был включен ? Или он был включен на дополнительной карте ? Тогда опять же вопрос - каким образом без уведомления ?',
#    ' Она будет направлена мне по интернету ли курьером ?',
#    ' Я вижу в интернет-банке , что мне начислено вознаграждение , когда данная сумма будет на счете ?',
#    ' Добрый день ! Я сегодня оплатила услуги интернета с кредитной карты <bankname> банка ( 111 руб ) На счету было 1111 руб , а теперь доступно 1 , почему ? И почему у меня подключена страховая защита , если мне ее отключали ?'],
#   'question': '20 . Будет ли мне доступна услуга интернет-банк ?'},
#  {'answer': 'Вы можете самостоятельно указать e-mail и подключить данную услугу в интернет-банке , мобильном банке или обратившись в центр обслуживания клиентов банка по телефону .',
#   'paraphrased_questions': [' Здравствуйте . Не могу оплатить интернет через приложение . Не даёт оплатить , т.к . Лицевой счёт начинается не с 11 , а нам в этом месяце изменили лицевой счёт для оплаты . Что делать ?',
#    ' Здравствуйте . Не могу оплатить интернет через приложение . Не даёт оплатить , т.к . Лицевой счёт начинается не с 11 , а нам в этом месяце изменили лицевой счёт для оплаты . Что делать ?',
#    ' оформил заявку на закрытие своего валютного вклада по окончанию срока через мобильное приложение , так как не нашел такой опции в веб-версии . при закрытии мне указало , что я получу сумму на 111 долларов меньше , чем накоплена сейчас . там какой-то налог ?',
#    ' Здравствуйте , мне нужна выписка по счетам , для шенгенской визы . Не подскажите как её получить ?',
#    ' здравствуйте , у сеня 1 номера , и я не могу оплатить счёт потому я отправка смс заблокированна по причине смены симкарты , что делать в этом случае ?'],
#   'question': '21 . При оформлении заявки через КЦ / интернет я не указывал e-mail и не получаю счет-выписку по e-mail , что делать ?'},
#  {'answer': 'По дебетовым картам : проценты на сумму пополнения начисляются со дня , следующего за днем поступления данной суммы на счет .',
#   'paraphrased_questions': [' Какой процент идёт на остаток по дебетовой карте ?',
#    ' И процент на остаток по карте на каких условиях начисляется ?',
#    ' ДО какой суммы на карте начисляются проценты на остаток ?',
#    ' Почему по дебетовой карте ставка на остаток 1 % , а не 1 ?',
#    ' Добрый день , подскажите момент по дебитовым карта . Интерисует процент на остаток на карте , а точнее с какой суммы он считается . С остатка на карте на момент выписки ?'],
#   'question': '22 . Когда начинают начисляться проценты на доступный остаток по дебетовой карте / перестают начисляться на сумму задолженности по кредитной карте ?'},
#  {'answer': 'В каждом ТСП имеются свои инструкции / рекомендации по изъятию карты . Ключевые основания для изъятия карты :',
#   'paraphrased_questions': [' если я буду снимать с рублевой дебетовой карты злотые в Польше , какой будет курс ?',
#    ' Подскажите.недавно были изменения по карте , какие услуги на моей карте ещё есть ? , годовое обслуживание какое ?',
#    ' я потеряла сим карту , к которой была привязана карта . как быть ?',
#    ' здравствуйте , отправили новую карту по адресу которому уже не проживаю , как быть ? или карта будет ждать меня в отделении почти ?',
#    ' Спасибо ! Какие есть способы оставить заявку на дополнительную карту ?'],
#   'question': '23 . В каких случаях карта может быть изъята сотрудником ТСП ?'},
#  {'answer': 'В случае отсутствия подписи на оборотной стороне карты в специально отведенном месте , карта считается недействительной , и вам может быть отказано в обслуживании .',
#   'paraphrased_questions': [' Уточнить хочу , на моей карте средства застрахованы ?',
#    ' здравствуйте , перестал работать *** **** на дебетовой карте , можно поменять карту ?',
#    ' Здравствуйте ! Как оставить заявку на продление карты ?',
#    ' Подскажите , моя заявка на доп карту обрабатывается ?',
#    ' Подскажите , как отправить заявку на выпуск валютных карт ?'],
#   'question': '24 . Зачем требуется подпись на карте ?'},
#  {'answer': 'Большинство банков используют именно этот способ доставки , как наиболее удобный и безопасный . Ваша карта доставляется вам заказным письмом с объявленной ценностью , которое вы можете получить непосредственно в вашем почтовом отделении . Доставка производится согласно Закону о федеральной Почтовой Службе , по которому почта берет на себя обязательства по доставке . Воспользоваться картой можно только после ее активации , при которой осуществляется идентификация держателя карты .',
#   'paraphrased_questions': [' Здравствуйте , а можно ли дополнительную дебетовую карту выслать по почте ?',
#    ' Здравствуйте ! Возможно ли изменение ТП по моей кредитной карте ?',
#    ' А SMS-информирование по дополнительной карте дополнительно оплачивается ?',
#    ' Здравствуйте . Можно ли отключить программу страхования по моей карте ?',
#    ' Можете ли Вы подсказать , существует ли какая-то задолженность по указанной карте ?'],
#   'question': '25 . Безопасно ли доставлять карту по почте ?'},
#  {'answer': 'Карта со статусом « GOLD » / « WORLD » / « Platinum » - это карта более высокого класса , чем « STANDARD » и « ELECTRON » . Премиальные карты пользуются большим доверием у торгово-сервисных предприятий , вероятность отказа в принятии карты со статусом « GOLD » / « WORLD » / « Platinum » к оплате минимальна . Также по картам высокого класса « GOLD » / « WORLD » / « Platinum » можно получать различные скидки в торгово-сервисных предприятиях по всему миру : при оплате картой в ресторанах , магазинах , бутиках , при бронировании отеля , аренде автомобиля .',
#   'paraphrased_questions': [' Хотел уточнить статус изготовления/отправки перевыпущенной карты ?',
#    ' Карта заблокирована , счет тоже . Что может измениться ?',
#    ' Мне нужна карта K***** . Обычная карта не нужна . Что посоветуете ?',
#    ' а чем отличается перевыпуск доп . карты от добавления еще одной доп.карты и закрытия старой доп.карты ?',
#    ' Здравствуйте ! Подскажите пожалуйста , что такое дополнительная карта ?'],
#   'question': '26 . Что означает статус карты « GOLD » / « WORLD » / « Platinum » ?'},
#  {'answer': 'Да , баланс по карте можно уточнить в банкоматах , обслуживающих карты платежной системы MasterCard / Visa ( в зависимости от платежной системы , которой принадлежит карта ) .',
#   'paraphrased_questions': [' скажите ещё , могу ли я пополнить баланс карты через банкамат сбербанка ?',
#    ' здравствуйте , я пополнила баланс . этот баланс автоматически уйдёт на кредит ?',
#    ' Баланс карты и доступный остаток - разница в том , что баланс карты может включать еще не списанные деньги ?',
#    ' здравствуйте , могу ли я пополнить процент на карту <bankname> со своей карты сбербанк ? и какой процент ?',
#    ' Могу ли я перевести часть денег со своей кредитной карты на свою дебетовую через личный кабинет ?'],
#   'question': '27 . Могу ли я через банкомат узнавать баланс ( доступный остаток ) своей карты ?'},
#  {'answer': 'Картой можно расплатиться практически в любом ресторане или кафе , во многих супермаркетах и торговых центрах , в других торговых и сервисных компаниях . Сеть приема пластиковых карт постоянно и быстро расширяется .',
#   'paraphrased_questions': [' Где теперь посмотреть акции на дебетовой карте T****** B**** ?',
#    ' Нашёл вкладку . Оформить дополнительную карту . Это виртуальная карта или именная ?',
#    ' Хочу перевести себе на карту с дургой карты . Просят номер догвоора . Где взять ?',
#    ' Здравствуйте , подскажите , где мне найти реквизиты моей карты ?',
#    ' Здравствуйте , подскажите , где мне найти реквизиты моей карты ?'],
#   'question': '28 . Где принимают карту ?'},
#  {'answer': 'Да , возможно , причем возможно пополнение не только карты , но и вклада .',
#   'paraphrased_questions': [' здраствуйте , можно ли перевести деньги с карты на карту ?',
#    ' Здравствуйте ! У меня вопрос по поводу кредитной карты . С кредитной карты можно перечислять деньги на счет дебетовой карты ? Если да , то с какой комиссией ?',
#    ' Здравствуйте ! Скажите пожалуйста , если кредит по карте погашен и задолженности по оплате нет , будет сниматься ежемесячная комиссия ( какая либо ) с карты ?',
#    ' Правильно ли я понимаю , что с рублевой карты я могу пополнить по реквизитам вклада , переведя деньги с карты на счет ? Или обязательно заказывать валютную карту ? И как банк осуществляет конвертацию ?',
#    ' Здравствуйте , я перевела деньги с кредитной карты на карты сбербанк , будет ли это считаться использованием наличных средств ? Пойдут ли проценты ?'],
#   'question': '29 . Возможно ли погашать задолженность по карте с помощью системы Web-Money и Яндекс.Деньги ?'},
#  {'answer': 'Можно снимать наличные в любом отделении любого банка , где принимается MasterCard / Visa ( в зависимости от платежной системы , которой принадлежит карта ) . При этом многие банки требуют ввести ПИН-код на терминале .',
#   'paraphrased_questions': [' Здравствуйте , подскажите можно ли в банке оформить реструктуризацию ?',
#    " Могу ли я оплатить кредит в банк `` Русский стандарт '' в Калужской области ?",
#    ' а в этих банкоматах сторонних банков могут снять комиссионные , или исключено ?',
#    ' может ли из-за того что в наименовании банка указан ЗАО ТКС банк , деньги не дойдут ?',
#    ' если я поеду в Казахстан , в каком банке снимать наличные ?'],
#   'question': '30 . Возможно ли снять наличные в отделениях банков ?'},
#  {'answer': 'Оплата мобильного телефона и коммунальных услуг возможна в банкоматах , в которых настроена данная функция . Тип операции зависит от настроек банкомата , т.е . возможно списание комиссии за совершение операции согласно тарифному плану . Также необходимо учитывать , что банк , которому принадлежит банкомат , может списывать свою комиссию за данную операцию .',
#   'paraphrased_questions': [' здравствуйте . подскажите , есть ли возможность оплаты квитанций через мобильное приложение по **-коду ?',
#    ' здравствуйте , хотелбы узнать , если с этой карты оплачивать кредит другого банка невыходя из дома через интернет будет ли взыматся комиссия или процент какой либо ? также оплата счетов мобильных телефонов штрафов гбдд и оплата коммунальных услуг ?',
#    ' что значит бесконтактным способ ? это оплата картой *** **** или оплата телефоном через *** ?',
#    ' подскажите , пож-та , через ИБ или мобильное приложение есть возможность оплаты ЖКХ в городе Уфа ?',
#    ' При оплате через мобильное приложение с помощью карты другого банка , зачисление в этот же день ?'],
#   'question': '31 . Возможна ли оплата мобильного телефона и коммунальных услуг через банкомат ?'},
#  {'answer': 'Наш банк выпускает все карты сроком на 5 лет . По истечении данного срока карта будет перевыпущена вам бесплатно .',
#   'paraphrased_questions': [' Подскажите , какой срок исполнения перевода с карты B**** на карту другого банка ?',
#    ' Добрый день ! Скажите пожалуйста какой контрольный срок прохождения денег с карты <bankname> банка на карту Сбер банка ?',
#    ' Здравствуйте ! У меня на дебетовой карте подключена услуга SMS-банк бесплатно ( акция ) . Сегодня я получил к этой карте дополнительную . SMS-банк на доп . карту будет платным или так же бесплатным до окончания срока у основной карты ?',
#    ' Хотела уточнить в какие сроки как правило провожается перевод средств на карту стороннего банка ?',
#    ' Жаль , значит по окончанию срока действия , я могу поменять на другую карту ?'],
#   'question': '32 . На какой срок банк выпускает мне карту ?'},
#  {'answer': 'С вашими денежными средствами ничего не случится , вам необходимо будет позвонить сразу же в банк , сообщить об утере и заблокировать карту . Банк перевыпустит вам карту и вы сможете продолжать ей пользоваться .',
#   'paraphrased_questions': [' здравствуйте , если я с карты зарплатной промсвязьбанка буду деньги карту ткс пепеводить будет ли комиссия ?',
#    ' если произойдет несчастный случай со мной , что будет с моими деньгами ?',
#    ' ясно . какой процент переплаты будет назначен , если я переведу деньги с карты на карту сбербанка ?',
#    ' Здравствуйте , хочу узнать , что будет , если кто-то завладеет моей дебетовой картой и будет расплачиваться ей бесконтактно . Я потом смогу вернуть деньги , т.к . злоумышленник не сможет подделать подпись ?',
#    ' сейчас мне заблокировали карту и перевыпускают новую . если мне придут деньги на старую карту ( по номеру карты ) что с ними будет ?'],
#   'question': '33 . Если я потеряю карту , что будет с деньгами ?'},
#  {'answer': 'Вы можете оформить перевод средств на ваш счет в другом банке , средства будут доступны в течение нескольких дней .',
#   'paraphrased_questions': [' Как мне вывести все деньги , если я хочу закрыть карту ?',
#    ' ну это я уже сделал . Хорошо спасибо за информацию . А если мне понадобиться полный номер карты ? как я могу его узнать ? или если деньги не придут получателю в течении 1 дней ? что мне делать ?',
#    ' а если мои родственники не знают что я тут деньги держу ?',
#    ' А что делать , если мне нужна дебетовая Рублёвая ?',
#    ' и что мне делать если меня забирают в армию и я не успею ее закрыть ?'],
#   'question': '34 . Если я потерял карту и еще не восстановил , а мне срочно нужны деньги – что делать ?'},
#  {'answer': 'Сумма покупки будет возвращена на счет клиента . В случае кредитной карты : проценты за пользование кредитом будут начислены .',
#   'paraphrased_questions': [' В смысле сбросить , если карта была получена вчера ?',
#    ' а что делать , если была произведена ошибка в реквизитах ?',
#    ' То есть она может быть использована в судебных разбирательствах , если вдруг что . Правильно ?',
#    ' если будет переплата , я , в случае необходимости , не смогу закрыть карту ?',
#    ' Что будет если привысить лимит на блек карте в 111к ?'],
#   'question': '35 . Что произойдет , если оплаченный картой товар будет возвращен в магазин ?'},
#  {'answer': 'Для проведения данной операции , пожалуйста , используйте SWIFT код нашего банка : TICSRUMM',
#   'paraphrased_questions': [' Здравствуйте , я новый клиент с дебетовой картой , пытаюсь ее пополнить с карты жены тоже вашей дебетовой в интернет банке переводом с карты на карту , система пишет операция запрещена , при этом она из своего личного кабинета может перевести , подскажите что не так делаю ?',
#    ' у вас есть процедура пополнения через приложение с карты другого банка , там можно отсканировать карту , ввести срок действия и *** код . как я понимаю в этом случае моя карта пополняется с карты другого банка не переоводом , а платежом как будто в интернет магазине ?',
#    ' Я и пользуюсь интернет банком на телефоне же . Вы не можете ее активировать ?',
#    ' еще вопрос появился ... сделала заявку на перевыпуск карты , ее заблокировали , но и в интернет-банке счет обнулился . получается , я не могу через интернет-банк пользоваться теми деньгами , что были на карте ?',
#    ' Добрый день ! Я пытаюсь перевести деньги с моей карты на мою же карту , но в другом банке . Причина - я сейчас в Новой Зеландии , а карту ТКС , оказывается , забыл дома . Система пишет , что сервис временно недоступен . Могу я узнать , когда сервис будет доступен ?'],
#   'question': '36 . Я пытаюсь перевести средства с интернет-сайта на карту вашего банка , но система запросила SWIFT-код . Вы можете его предоставить ?'},
#  {'answer': 'Наш банк выпускает карты , оснащенные магнитной полосой , данные на которой хранятся в зашифрованном виде , а также карты с магнитной полосой и микрочипом , который обеспечивает дополнительный уровень защиты : подделка чипованной карты практически невозможна . Дополнительную защиту всех карт <bankname> банка при совершении операций в интернете обеспечивает сервис « MasterCard SecureCode » [ МастерКард СекьюрКод ] / « Verified by Visa » [ Верифайд бай Виза ] . При совершении покупок в интернет-магазинах , поддерживающих данную технологию , на мобильный телефон клиента поступает SMS с параметрами покупки и одноразовым кодом для подтверждения операции . Без этих кодов мошенники не смогут совершить покупку .',
#   'paraphrased_questions': [' с карты другого банка на мою карту <bankname> ? между картами банка <bankname> не учитываются ?',
#    ' Глеб , скажи какой годовой % по кредитной карте <bankname> банк ?',
#    ' Добрый день ! Подскажите , какая комиссия берётся банком за перевод по номеру карты с карты <bankname> блэк на карту другого банка ?',
#    ' Добрый день ! подскажите сколько стоит перевод скредитной карты <bankname> банка , на карту другого банка ?',
#    ' Здравствуйте ! Сколько по времени занимает перевод с кредитной карты <bankname> на дебетовую карту другого банка , если карта другого банка привязана в личном кабинете ?'],
#   'question': '37 . Какой степенью защиты обладают карты <bankname> Банка ?'},
#  {'answer': 'Да , в написание имени и фамилии на карте можно внести изменения в соответствии с правилами транслитерации . В случае , если фамилия и имя , указанные на карте , отличаются от данных , указанных в загранпаспорте , только по написанию , но не отличаются по звучанию , такая ситуация НЕ может быть причиной отказа в обслуживании карты .',
#   'paraphrased_questions': [' Предусмотрены ли штрафные санкции , в случае возникновения на карте T****** ***** овердрафтов ?',
#    ' здравствуйте , подскажите пожалуйста в случае перечисления денежных средств с моей карты <bankname> на карту физического лица в сбербанке будет ли списана комиссия и если да то в каком размере ?',
#    ' Когда получал карту в имени на карте имя не верно указано , правильное D***** а написано D****** это на что-то влияет , нужно ли перевыпускать ?',
#    ' Здравствуйте ! В случае открытия карты в евро , по какому курсу происходит зачисление денежных средств на карту ? Могу ли я пополнять ее при помощи рублевой карты ?',
#    " В приложении указано три курса : `` по договору кредитной карты '' и `` с использованием карты '' . На какой мне ориентироваться в данном случае ?"],
#   'question': '38 . Транслитерация имени на карте не совпадает с транслитерацией имени в загранпаспорте / других документах . Может ли такое различие послужить причиной отказа в обслуживании карты ? Можно ли внести изменения в транслитерацию имени на карте ?'},
#  {'answer': 'В банке установлен лимит на максимальное количество операций , совершаемых в сутки - не более 20 операций .',
#   'paraphrased_questions': [' Т.е получается , если в течении месяца на счете сумма будет меньше 11111 хотя бы три день , то произойдет списание ?',
#    ' Каждый день - имеется ввиду на начало дня ? Если я совершил покупку , в результате которой на счету стало 11111 рублей , и в течение минуты сделал перевод на счёт , увеличивший баланс снова до 11111 , спишется ли плата за обслуживание ?',
#    ' То есть в конце расчетного периода будет перерасчет исходя из ставки 1 % ( если я накуплю на 1 т. в течение месяца ( ?',
#    ' Подскажите , пожалуйста , а если я сниму наличные в размере 11 111 , то сколько будет на них проценты начислены ? и расчет за эту сумму происходит также как обычно , в течение 11 дней-льготный период ?',
#    ' ясно . т.е . не в конце отчетного периода ( месяц ) , а в течение суток ?'],
#   'question': '39 . Существуют ли ограничения на количество операций , совершаемых в течение дня / месяца и т.п . ?'},
#  {'answer': 'При снятии наличных с карты нашего банка вы можете выбрать в меню банкомата любой тип счета , этот параметр не влияет на прохождение операции .',
#   'paraphrased_questions': [' Подскажите какие лимиты на снятие наличных в банкомате Райфайзен и Альфа-банк ?',
#    ' И какой курс конвертации при снятии в Грузии местной валюты - лари ?',
#    ' а при снятии в любом другом банкомате комиссия не берется ?',
#    ' а какой лимит на снятие наличных в банкомате в день ?',
#    ' здравствуйте ! при снятии денег в белоруссии банкоматом какого банка воспользоватся чтобы не сняли процент ? ?'],
#   'question': '40 . Какой тип счета выбирать при снятии наличных в банкомате ( например : текущий , кредитный , сберегательный ) ?'},
#  {'answer': 'Да , правомерно . Документ , удостоверяющий вашу личность , может потребоваться в целях безопасности в соответствии с правилами , установленными в данном ТСП .',
#   'paraphrased_questions': [' Будут ли в таком случае запрашиваться коды подтверждения при оплате в интернет-магазинах ?',
#    ' Здравствуйте ! При оплате по шаблону в ИБ должно приходить смс с кодом подтверждения операции ?',
#    ' здравствуйте , хочу дать в пользование дебитовую карту своему брату , он проживает в Тайланде при проведении операции в онлайн банке , нужны ли какие нибудь подтверждения типо смс и тп ?',
#    ' Здравствуйте ! При покупке в интернет магазине в долларах это операция по картсчету или операция с использованием реквизитов карты ?',
#    ' еще вопрос- при оплате в S*** **** ******* ***** можно ли добавить дополнительное подтверждение по смс-коду ?'],
#   'question': '41 . Правомерно ли требование кассира предъявить документ , удостоверяющий личность , при совершении операции в ТСП ?'},
#  {'answer': 'Отличие карты с чипом от обычной карты заключается в том , что при считывании информации используется либо магнитная полоса , либо встроенный в карту микрочип с данными ( в зависимости от возможностей терминала ) . Микрочип обеспечивает дополнительный уровень защиты : подделка чипованной карты практически невозможна .',
#   'paraphrased_questions': [' а чем отличается перевыпуск доп . карты от добавления еще одной доп.карты и закрытия старой доп.карты ?',
#    ' А от чего зависит срок перевода с карты на карту ?',
#    ' Здрасте . Почему не могу пополнить карту с карты сбербанка ?',
#    ' какой пункт лучше ? С карты на карту ? Организациям ?',
#    ' Почему не получается пополнить карту <bankname> с карты втб ?'],
#   'question': '70 . Чем отличается обычная карта от карты с чипом ?'},
#  {'answer': 'Карта с PayPass [ « пэй пас » ] - карта с чипом и технологией бесконтактной оплаты покупок . Для совершения покупки достаточно приблизить карту к специальному терминалу , поддерживающему данную технологию . Это удобно и безопасно .',
#   'paraphrased_questions': [' А с чего вы решили , что была замена сим карты . Откуда такая информация ?',
#    ' Аа , поняла . Нет не запрашивала , а что с картой ?',
#    ' Поясните , что значит банковским . Стандартное пополнение с другой карты не подойдет ?',
#    ' Не подскажете что выгоднее ? Совершать покупки с картой *B** ?',
#    " С чем связана ошибка `` Ваша карта не может быть обработано '' ?"],
#   'question': '42 . Что такое карта с PayPass ?'},
#  {'answer': 'VISA и MasterCard являются наиболее распространенными международными платежными системами , которые предоставляют качественный сервис и безопасность проведения платежей на одинаково высоком уровне .',
#   'paraphrased_questions': [' новый лк дает какие то новые функии или это просто визуальные изменения ?',
#    ' Ваша система восстановилась или какое то время еще нужно подождать ?',
#    ' Это произойдет автоматически или нужна какая то заявка ?',
#    ' Да , конечно , на какой е-мейл и какую тему письма поставить ?',
#    ' Каким способом я должен отправить письмо и в какой форе ?'],
#   'question': '43 . Какая платежная система лучше VISA или MasterCard ?'},
#  {'answer': 'При совершении операции в интернет-банке , мобильном банке или через центр обслуживания клиентов фактический курс клиент сможет узнать непосредственно перед совершением операции .',
#   'paraphrased_questions': [' Конвертация будет происходить по вашему внутреннему курсу или по курсу банка Греции ?',
#    ' по какому курсу списываются денежные средства , если оплата произведена в валюте ?',
#    ' здравствуйте , по какому курсу произойдет конвертация в доллары в данный момент ?',
#    ' А можно узнать , каким образом будет проходить конвертация к примеру из рубли в тенге ? по какому курсу ?',
#    ' то есть сумма в долларах списывается по курсу вашего банка или по курсу цб ?'],
#   'question': '44 . По каким курсам осуществляется конвертация валют в <bankname> Банке ?'},
#  {'answer': 'Если карта перевыпущена по причине окончания срока действия ( пролонгация ) , персонализации или изменения типа карты – номер карты и ПИН–код сохраняются .',
#   'paraphrased_questions': [' забыл пин код карты , карта заблокирована . как восстановить ?',
#    ' Привет , подскажите как менять код блокировки на телефоне ? И есть ли функция смены пинкода карты ?',
#    ' есть ли возможность сменить пин код карты через банкомат ?',
#    ' Хотел узнать , могу ли я сам изменить пин код дебетовой карты , например в банкомате ?',
#    ' Здравствуйте ! Я неправильно ввел пин код карта заблокировался ! Можно разблокировать карту и поменять пинн-код ?'],
#   'question': '45 . Будут ли изменены номер карты и ПИН-код в случае перевыпуска карты ?'},
#  {'answer': 'Если ПИН-код был введен неверно 3 раза подряд , возможность совершения любых операций по карте блокируется . Для того , чтобы вы могли воспользоваться данной картой , вам необходимо обратиться в наш банк для разблокировки .',
#   'paraphrased_questions': [' Добрый день ! Я хотела узнать почему мои платежи через терминал в магазинах проходят без набора пин-кода ? И есть ли возможность поменять пин-код и отключить смс оповещения ?',
#    ' Здраствуйте ! я давно не пользовалась своей картой через пин -код.в основном пэйпасс . забыла пин-код . как восстановить ?',
#    ' Я направила запрос на изменение способа идентификации ( с пин-кода на подпись ) , но для этого потребуется операция в банкомате , а значит старый пин-код , правильно ?',
#    ' добрый вечер . Возникла проблема . не правильно ввел пин-код ( видимо не первый раз не правильно ) и когда ввел уже правильный пин-код , мне все равно не получилось совершить платеж в магазине . Подскажите , что делать , как сменить/восстановить пин-код ? ?',
#    ' здравствуйте , подскажите , могу ли я изменить ПИН -код ?'],
#   'question': '46 . Я неверно ввел ПИН-код 3 раза подряд . Могу ли я после этого совершать покупки в магазинах ( торгово-сервисных предприятиях ) без введения ПИН-кода ?'},
#  {'answer': 'В зависимости от типа карты в приоритете может быть как подпись клиента , так и пин-код .',
#   'paraphrased_questions': [' Здравствуйте ! Почему при оплате в магазине картой картоприёмник не требует пин код ?',
#    ' здравствуйте . почему при оплате картой в терминалах не запрашивается пин код ?',
#    ' Здравствуйте ! Почему на доп карте при покупках терминал не требует пин кода ?',
#    ' Здравствуйте . При покупке в магазинах , оплате счетов в ресторанах картой не запрашивается пин-код , а требуется подпись . Можно ли изменить авторизацию на пин-код ?',
#    ' сегодня при оплате терминал не запросил пин-код . это тоже в норме ?'],
#   'question': '47 . Почему при оплате в магазине по карте <bankname> Банка требуется / не требуется ввод ПИН-кода .'},
#  {'answer': 'Вы можете снимать наличные в любых банкоматах и пунктах выдачи наличных , которые обслуживают карты MasterCard / Visa .',
#   'paraphrased_questions': [' Подскажите мне пожалуйста , где я могу снять доллары в районе метро Беляево ?',
#    ' Можете подсказать , где мне найти ближайшего партнера ?',
#    ' подскажите , пожалуйста , если я хочу снять 111 т.р . где я могу это сделать ? В любом банкомате ?',
#    ' конкретно сейчас я иду к атм сколько я потрачу сняв 111 евро ?',
#    ' конкретно сейчас я иду к атм сколько я потрачу сняв 111 евро ?'],
#   'question': '48 . Где я могу снять наличные ?'},
#  {'answer': '<bankname> Банк – надежный банк , успешно работающий во всех регионах России , у нас более 4 миллионов клиентов . Все вклады в нашем банке до 1,4 млн рублей застрахованы государством и вы ничем не рискуете . Вы можете быть уверенными в надежности нашего банка . Дополнительную и детальную информацию о финансовом состоянии нашего банка вы можете узнать в надежных официальных источниках , например , на официальном сайте ЦентроБанка ( www.cbr.ru ) или на нашем официальном сайте www.tinkoff.ru .',
#   'paraphrased_questions': [' Еще вопрос ... заявление в банк о предоставлении копий по кредитному делу имеет ваш формат или свободный ?',
#    ' Информирует ли банк клиентов о поступивших исполнительных документах и инкассовых поручениях ?',
#    ' Но почему приходит уведомление от <bankname> банка о блокировки счета <bankname> банка ?',
#    ' О ! Ещё вопрос . За проценты и кэшбек моим налоговым агентом выступил банк ?',
#    ' Просто на мой вопрос , какова цель звонка , он ответил , что в целях напоминания о платеже . Тогда его вопрос о планируемой дате мне не понятен . Можно ли узнать это был действительно сотрудник Банка ?'],
#   'question': '49 . Вопросы о надежности <bankname> Банка'},
#  {'answer': 'Банк существует с 1994 года . Все это время банк официально зарегистрирован в Центральном Банке РФ , входит в ГОСУДАРСТВЕННУЮ систему страхования , имеет свой регистрационный номер и лицензию . Эту информацию можно увидеть на официальном сайте ЦБ РФ www.cbr.ru . Ранее банк назывался « Химмашбанк » . С января 2007 года название банка было изменено на « <bankname> Кредитные Системы » . Название « <bankname> Банк » используется с января 2015 года , с апреля 2015 года банк официально перешел на новое наименование .',
#   'paraphrased_questions': [' Как являясь клиентом банка оставить заявку на рассмотрение ипотеки ?',
#    ' На основании чего удостоверяет банк доверенное лицо ?',
#    ' вы как представитель банка можете выслать квитанцию мне на ***** ?',
#    ' Можно как то перевести деньги на карту приват банка на Украине ?',
#    ' Ипотека в <bankname> банке предоставляется только на квартиры ?'],
#   'question': '50 . Как давно <bankname> Банк существует на рынке ?'},
#  {'answer': 'Единственным акционером ( 100 % уставного капитала банка ) является компания ТиСиЭс Груп Холдинг ПиЭлСи ( TCS GROUP HOLDING PLC ) .',
#   'paraphrased_questions': [' <bankname> банк предоставляет ипотеку ? Или банк партнер ?',
#    ' хорошо , допустим , банк получатель и банк отправитель <bankname> - возможность отмены есть ?',
#    ' банк осуществляет продажу солотых и серебрянных слитков ?',
#    ' Банк корреспондент это банк который принимает долларовые переводы и переводит в ваш банк ?',
#    ' Чем отличается SWIFT Получателя и SWIFT банка Корреспондента ?'],
#   'question': '51 . Кто является владельцем банка ?'},
#  {'answer': 'Герб , размещенный на логотипе <bankname> Банка , - герб рода <bankname> , который берет свое начало в XV веке . Род <bankname> внесен в гербовник родовой книги Московской и Орловской губерний .',
#   'paraphrased_questions': [' почему Вы считаете , что именно это подразумевается , на основани какого документа ?',
#    ' Несмотря на то , что вы видите , что это та же точка ?',
#    ' так на основании чего вы решили , за какое обслуживание это плата ?',
#    ' Имя , а что значит за расчетный период ? Вернее я понимаю что это значит , но какой он ?',
#    ' это хорошо , что Вы видите , только я не пойму , на какую карту кликнуть . В каком разделе ?'],
#   'question': '52 . Что значит год « 1759 » на вашем логотипе ? Логотип напоминает какой-то древний герб – что это за герб , какое он отношение имеет к вам ?'},
#  {'answer': 'Олег <bankname> – известный предприниматель , основатель компаний « Петросиб » ( сеть магазинов « Техношок » и « МusicШок » ) и « Дарья » ( продукты легкого приготовления ) , компаний <bankname> ( создание сети пивоварен и выпуск пива <bankname> ) .',
#   'paraphrased_questions': [' ** , каким образом забрать свои деньги - если такое произошло ?',
#    " а ООО `` евросеть-ритейл '' является таким партнёром ?",
#    ' здравствуйте . перевод с долларовой карты <bankname> на долларовую <bankname> другого клиента возможен ?',
#    ' Почему КБК 11111111111111111111 <bankname> считает ошибочным ?',
#    " 1 ) это как-то отключается ? 1 ) какие комиссии на такого рода `` овердрафт '' ?"],
#   'question': '53 . Кто такой Олег <bankname> ?'},
#  {'answer': 'Лицензия Банка России на право осуществления банковской деятельности № 2673 от 28 января 1994 года была обновлена 24 марта 2015 года в связи с ребрендингом банка . Данная лицензия бессрочная .',
#   'paraphrased_questions': [' 1 % годовых начислчется от суммы , которая лежит на карте на расчетную дату ?',
#    ' Ого . срок платежа с моей стороны в этом случае от какой даты считается ?',
#    " а дата повышения ставки будет рассчитываться на основании даты покупок на 1111 руб , или даты обработки платежа ( перехода из статуса `` авторизация '' в `` транзакция '' ) ?",
#    ' А указанная в выписке дата возврата - это дата по чеку , или жата фактического поступления денег на счёт ?',
#    ' В спец предложениях есть информация о скидке 11 % в магазинах **** при покупке от 1111р . Только что сделал покупку на 1111 рассчитывая на эту скидку ... ее нет ! Почему ?'],
#   'question': '54 . Почему информация о дате выдачи лицензии , указанной на сайте ( 28 января 1994 г . ) отличается от даты , указанной непосредственно в документе « Лицензия на осуществление банковских операций » ( 24 марта 2015 г . ) / Какой срок действия данной лицензии ?'},
# ...
#    ' где теперь можно посмотреть предложения , где кешбэк до 11 % ?'],
#   'question': '160 . Где можно увидеть вашу рекламу ?'},
#  {'answer': 'Да , это действительно так , для вас нет риска вкладывать деньги в наш банк : у нас привлекательные проценты по вкладам , и , безусловно , сумма до 1,4 млн рублей ( для валютных вкладов рублевый эквивалент данной суммы ) застрахована государством .',
#   'paraphrased_questions': [' Правильно ли я понимаю , что по дебетовой карте процент на остаток на счете составляет 1 % для суммы до 111111 , а что свыше - 1 % ?',
#    ' Мне перевыпустили карту Блэк . В сопроводительном письме указано , что максимум на остаток на счёте начисляется на остаток до 111 т.руб . Относится ли это условие ко мне , если при заключении договора ранее это условие действовало на остаток не превышающий 111 т. рублей ?',
#    ' Вот смотрите то есть я пополняю счёт на сумму 111 рублей и с меня снимут только проценты на дату формирования выписки это как правило около 111 рублей примерно так ?',
#    ' Я так предполагаю , когда я оплачиваю минимальную сумму то на счете должен быть какой-то положительный баланс , в итоге до этого сняли около 1тр сейчас 1.111 и ещё минус . Я не могу понять у меня 11111 только проценты ? ? ?',
#    ' здравствуйте , пополнила карту через евросеть , сумма 1111 , пишет что на счету доступно 1111 , запись что минимальный платеж необходимо сделать до 11.11 до сих пор не пропала и сумма задолженности теперь стоит 11111 , а была 11111 ( точно уже не помню ) хотелось бы уточнить почему такие цифры ?'],
#   'question': '161 . Мне известно , что государство страхует вклады вкладчиков на сумму до 1,4 млн рублей , так ли это ?'},
#  {'answer': 'Да , вы можете оформить заявку на перевод на ваш счет в другом банке или на почтовый перевод обратившись в центр обслуживания клиентов .',
#   'paraphrased_questions': [' Т.е . я не могу пополнить вклад , не обойдя банковскую карту ?',
#    ' Здравствуйте . Могу ли я пополнить долларовую карту наличными долларами ?',
#    ' приветствую ! могу ли я оформить дебетовую долларовую карту ?',
#    ' Здравствуйте , я открыл долларовый счёт , вместе с ним я получил дебетовую карту . Скажите могу ли я пополнять счёт путём внесения денежных средств на карту ?',
#    ' Подскажите , могу ли я восстановить пинкод карты ?'],
#   'question': '162 . Могу ли я изъять вклад , не получив пластиковую карту ?'},
#  {'answer': 'Мы отвечаем современным требованиям рынка и предлагаем широкий набор продуктов для наших клиентов . Валютные вклады - это распространенный и удобный инструмент для сохранения личных средств . При этом ваши валютные вклады также , как и рублевые защищены системой Государственного страхования вкладов , в которую входит наш банк .',
#   'paraphrased_questions': [' Здравствуйте ! Хочу узнать выдаёт ли ваш банк ипотеку ?',
#    ' Почему я должен страдать и испытывать постоянные неудобства по вине вашего банка ?',
#    ' Почему я должен страдать и испытывать постоянные неудобства по вине вашего банка ?',
#    ' Почему я должен страдать и испытывать постоянные неудобства по вине вашего банка ?',
#    ' Почему я должен страдать и испытывать постоянные неудобства по вине вашего банка ?'],
#   'question': '163 . Почему ваш банк начал заниматься валютными депозитами ?'},
#  {'answer': 'Эта услуга позволит вам контролировать все расходные операции по карте ( оплата картой ; снятие наличных ; перевод на другие счета ) .',
#   'paraphrased_questions': [' Какие уведомления мне будут недоступны , если ч отключу смс-банк ?',
#    ' подскажите , если я включу пуш уведомления в мобильном банке - это будет платно по тарифам смс ?',
#    ' Почему я снова вижу плату на смс банк в выписке если я эту услугу отключила ? ? ?',
#    ' Добрый день ! Сегодня я пополнил долларовую карту ( впервые ) и заметил , что пришла СМС , хотя мобильный банк для этой карты был отключен . Зайдя в услуги по карте я увидел , что он-таки включен . Я его тут же отключил . Подскажите , будет ли списана плата за мобильный банк по этой карте ?',
#    ' Здравствуйте ! Хотелось бы уточнить . 11 марта с меня списали 11 р за СМС банк . Хотя при обращении в банк месяцем ранее мне эту услугу должны были отключить . В итоге мною СМС банк была вручную отключена через интернет-банк . Как так получилось , что СМС банк был включен ? Или он был включен на дополнительной карте ? Тогда опять же вопрос - каким образом без уведомления ?'],
#   'question': '164 . Какая информация будет приходить на мобильный телефон , если я подключу услугу SMS-банк ?'},
#  {'answer': 'Кредитные карты : стоимость данной услуги составляется всего 39 или 59 рублей в месяц . Дебетовые карты : cтоимость данной услуги составляет всего 39 рублей в месяц ( 1 USD / 1 EUR для валютных карт ) .',
#   'paraphrased_questions': [' Плата за предоставление услуги SMS-банк , каким оброзом эта услуга подключилась ?',
#    ' средства за услугу смс банк списываются ежемесячно ?',
#    ' скажите когда банк возьмет плату за обслуживание карты ?',
#    ' Подскажите я могу отказаться от предоставления услуги ***-банк и платы за обслуживание ?',
#    ' Здравствуйте ! С меня была списана комиссия за услугу ***-банк , хотя сама услуга не подключена . Почему ?'],
#   'question': '165 . Взимается ли плата за услугу SMS-банк ?'},
#  {'answer': 'Система страхования вкладов – государственная структура , основной задачей которой является защита сбережений населения , размещаемых во вкладах и на счетах в российских банках на территории РФ . При наступлении страхового случая в отношении банка - участника системы страхования вкладов - клиентам этого банка государством будут возмещены суммы их вкладов . Максимальная сумма страховой выплаты ( включая проценты ) составляет 1,4 млн . рублей .',
#   'paraphrased_questions': [' ну что к нему относится - то что квартиру сдаю и вклады имею - это подходит ?',
#    ' это не смотря на то что счет карты приносит доход как вклад ?',
#    ' Добрый вечер . Изучал приложение и , читая о вкладе , случайно нажал « открыть вклад » , и он без подтверждения действия открылся , но , как я понимаю , не активен , т.к . я его не пополнял . Сразу же попытался закрыть вклад , было сказано что заявка на закрытие подана , но вклад не закрылся . Скажите , сколько времени это займет и будут ли какие-то последствия ? В тарифе вклада прочитал , что открытие вклада в банке стоит 1111р . Относится ли это к открытию через приложение , и снимут ли их , если вклад не был активирован ?',
#    ' Да . При закрытии существующего вклада , только что пролонгированного вклада , что то теряется ?',
#    ' Я не понимаю . Все сотрудники Банка говорят разную информацию . Кредит загашен , договор расторгнут , деньги обнулены , счёт заблокирован . Что ещё надо , что-бы эта карта с поле зрения исчезла ?'],
#   'question': '166 . Что такое « Система страхования вкладов » ?'},
#  {'answer': 'Все причитающиеся проценты по вкладу ( начисленные по день , предшествующий дню отзыва лицензии ) причисляются к основной сумме вклада и включаются в расчет страхового возмещения .',
#   'paraphrased_questions': [' Подскажите , когда начисляются проценты по вкладу смарт ?',
#    ' Подскажите , ушел ли платеж по закрытому вкладу 11.11 ?',
#    ' Здравствуйте . Начисляются ли проценты на остаток по счёту дебетовой карты ?',
#    ' Здравствуйте ! Скажите , пожалуйста , застрахованы ли накопительные счета Агентством по страхованию вкладов ?',
#    ' Скажите , есть ли ограничения по снятию средств по вкладу ?'],
#   'question': '167 . Страхуются ли проценты по вкладу ?'},
#  {'answer': 'Да , условия страхования распространяются на любые средства , размещенные физическими лицами в нашем банке , в том числе находящиеся на карте / накопительном счете . Начисленные проценты также застрахованы . Максимальная сумма страховой выплаты на одного клиента составляет 1,4 млн рублей* . Но это не означает потерю денежных средств свыше 1,4 млн рублей , т.к . у нашего банка есть активы , реализуя которые государство будет обязано исполнить все обязательства по выплате денежных средств , независимо от суммы .',
#   'paraphrased_questions': [' Ааааа ... На кредитный счёт зачислено . А почему не на дебетовую карту ? ! ? ! ?',
#    ' Зачислять лучше на счет . Потом на карту . Или просто на карту ?',
#    ' Предусмотрены ли штрафные санкции , в случае возникновения на карте T****** ***** овердрафтов ?',
#    ' а на накопительный счет USD страхование АСВ тоже распростроняеться ?',
#    ' Может ли иностранный работодатель переводить денежные средства на кредитную карту T****** ?'],
#   'question': '168 . Распространяются ли условия страхования на средства , находящиеся на дебетовой карте / накопительном счете ?'},
#  {'answer': 'При одобрении кредита наличными банк резервирует для вас кредитную линию . В случае неиспользования кредита наличными в течение 60 календарных дней с момента формирования счета* будет автоматически закрыт , а получение кредита наличными станет недоступно . Договор по продукту кредит наличными вступает в силу после активации продукта ( перевод средств с кредитного договора на дебетовую карту ) .',
#   'paraphrased_questions': [' Понял . В течении какого срока после блокировки возможен перевыпуск карты ( дополнительной } ?',
#    ' Понял . Баланс может оставаться отрицательным любое время или мне необходимо пополнить карту в течение определённого срока ?',
#    ' После осуществления перевода , в течение какого времени я могу оплатить без процента ?',
#    ' в течении какого срока должны поступить денежные средства ?',
#    ' а в течении какого времени после получения карты я могу рассчитывать на увеличение лимита ?'],
#   'question': '169 . В течение какого срока после одобрения заявки необходимо активировать « Кредит наличными » ?'},
#  {'answer': 'Проценты на проценты не начисляются . Часть регулярного платежа распределяется на погашение процентов , часть - на погашение основного долга . При внесении платежа , начисленные проценты погашаются в первую очередь .',
#   'paraphrased_questions': [' подскажите , начисляются ли проценты на остаток на виртуальной карте ?',
#    ' А как начисляются проценты на остаток свыше 111111 ?',
#    ' Если он выше то Проценты начисляются Ежедневно на остаток ?',
#    ' Подскажите какой процент начисляется на остаток и когда ?',
#    ' А начислилось как будто меньше . По какой ставке начислились проценты на остаток ?'],
#   'question': '170 . Начисляются ли проценты на проценты ?'},
#  {'answer': 'Сумма последнего платежа может быть увеличена за счет процентов , начисленных в период с момента перевода до момента формирования ближайшей выписки по КН . Сумма внесенного регулярного платежа в первую очередь пойдет в счет погашения этих процентов , поэтому в счет погашения основного долга будет распределена несколько меньшая сумма . Таким образом , на момент окончания срока кредита , небольшая часть суммы основного долга останется непогашенной . Этот небольшой остаток основного долга будет приплюсован к сумме последнего платежа .',
#   'paraphrased_questions': [' орентировочный минимальный платеж на следущий месяц какой ?',
#    ' Добрый день . Платежи от 11.11.1111 , а минимальный платеж назначен на 11.11 от какого числа считать ?',
#    ' Здравствуйте , как можно узнать сумму ежемесячного платежа и можно ли считать мой платеж сегодня , как платеж за месяц ?',
#    ' следующий мин платеж 11 а зарплата 11 , за 1 дня сколько накапает ?',
#    ' Однако , пропущенный платеж за три раз я погасить не смогу . Возможно ли уменьшение минимального платежа ?'],
#   'question': '171 . Может ли платеж за последний месяц отличаться от регулярного ежемесячного платежа ?'},
#  {'answer': 'Нет , комиссия за перевод на дебетовую карту НЕ взимается согласно тарифному плану по КН .',
#   'paraphrased_questions': [' Подскажите , разве должна сниматься комиссия за снятие наличных в любых банкоматах ?',
#    ' берется ли какая-либо комиссия за оспаривание транзакции ?',
#    ' Подскажите , за снятие денежныж средств , какова комиссия ?',
#    ' Хотелось бы узнать есть ли ещё Комиссия за пополнение наличными свыше 111 тысяч ?',
#    ' Здравствуйте , скажите пожалуйста сколько начислится комиссии за снятие наличных в банкоматах ?'],
#   'question': '172 . Взимается ли комиссия за выдачу кредита наличными ?'},
#  {'answer': 'Услугой можно пользоваться несколько раз . Вы можете подать заявку на новый кредит наличными после погашения задолженности по текущему кредиту .',
#   'paraphrased_questions': [' я бы хотел воспользоваться услугой перевод баланса . я могу воспользоваться этой услугой сегодня ?',
#    ' добрый день , мне сказали.что я могу воспользоваться услугой беспроцентного снятия наличных ? еще актуально ?',
#    ' Добрый день . Я сегодня погашу полностью потребительский кредит . Когда я смогу воспользоваться картой ?',
#    ' Скажите я только 1 раз могу воспользоваться беспроцентным платежом 11 дней ?',
#    ' Добры день ! Если я 11 апреля совершаю покупку то какого числа первый раз мне нужно пополнить счёт ?'],
#   'question': '173 . Сколько раз я могу воспользоваться предложенной услугой « Кредит наличными » ?'},
#  {'answer': 'Заявку на кредит наличными могут подать граждане РФ в возрасте от 18 до 70 лет - для женщин , от 20 до 70 лет - для мужчин , имеющие регистрацию ( постоянную / временную ) на территории РФ .',
#   'paraphrased_questions': [' Здравствуйте ! Могу ч воспользоваться услугой погашения кредита в другом банке ?',
#    ' я бы хотел воспользоваться услугой перевод баланса . я могу воспользоваться этой услугой сегодня ?',
#    ' добрый день , мне сказали.что я могу воспользоваться услугой беспроцентного снятия наличных ? еще актуально ?',
#    ' Добрый вечер , можно ли воспользоваться картой сверх лимита ?',
#    ' Здравствуйте ! Я оплатил задолжность , когда могу начать пользоваться картой ?'],
#   'question': '174 . Кто может воспользоваться услугой « Кредит наличными » ?'},
#  {'answer': 'Банк не может в одностороннем порядке повысить ставки в соответствии со статьей 29 Федерального закона « О банках и банковской деятельности » .',
#   'paraphrased_questions': [' может ли мне банк предоставить график погашения задолженности включая проценты ?',
#    ' Добрый день ! Прошу пояснить порядок снятия денежных средств по депозитному вкладу по окончании срокаи взимаются ли банком или партнером банка проценты за снятие ?',
#    ' Добрый вечер ! Подскажите , возможно ли в банке пролонгировать вклад по текущей процентной ставке ?',
#    ' Добрый день ! Подскажите пожалуйста , когда закрытие вклада , взымается ли процент по снятию ден.средств если переводить на карту или в банк ? И есть ли лимит по снятию ?',
#    ' Здравствуйте ! Скажите пожалуйста , а возможно-ли снизить процентную ставку по кредиту ?'],
#   'question': '175 . Может ли банк увеличить процентную ставку по кредиту наличными ?'},
#  {'answer': '- У Вас будут выгодные условия по тарифу на кредит наличными .',
#   'paraphrased_questions': [' Здравствуйте , если Я хочу досрочно закрыть свой кредит наличными , какие мои действия ?',
#    ' Сейчас вы как выдаете кредит наличными , если у вас нет на новом сайте раздела кредит наличными ?',
#    ' Добрый вечер , мне одобрили кредит наличными , как узнать условия ?',
#    ' здравствуйте , можно узнать почему мне отказывают в кредите наличными ?',
#    ' здрасте а если я щас пополню счет кредит лимит повыситься ?'],
#   'question': '176 . Зачем нужен « Кредит наличными » ?'},
#  {'answer': 'Кредит наличными ( КН ) – это продукт <bankname> Банка - кредит , предоставляемый клиенту за счет перевода средств со специального кредитного счета на дебетовую карту <bankname> Банка .',
#   'paraphrased_questions': [' Хотел узнать - что такое льготное снятие наличных ?',
#    ' Можете подсказать , что такое льготное снятие наличных ?',
#    ' Да , я заметила , что расходы значительно превысили поступления денежных средств . Какова вероятность того , что мне оформлен какой то кредит ?',
#    ' Здравствуйте , если Я хочу досрочно закрыть свой кредит наличными , какие мои действия ?',
#    ' Может быть такое что я покрою всю задолженность ( 11111 ) , а потом окажется что нет ?'],
#   'question': '177 . Что такое кредит наличными ?'}]

# %%
with open('FAQ_PROJECT_DATA.json', 'w') as f:
    json.dump(FAQ, f)

# %% [markdown]
# ### Run Engine

# %%
DATA_PATH = './FAQ_PROJECT_DATA.json'

engine = ENGINE_3(DATA_PATH, w2v_model)

# %%
# recall scores
r1, r3 = calc_score_for_engine(engine, DATA_PATH)
# Out:
# recall @1: 0.8514619883040936
# recall @3: 0.9812865497076023

# %% [markdown]
# ### Run Telegram bot

# %% [markdown]
# !!! Before starting the bot you should get a TOKEN and put it in config.py
#
# How to get a new token:
# * find @BotFather
# * write /newbot
# * write in bot_name and user_name
# * get a token for the new bot

# %%
from config import TOKEN, LOG_FILE

# Enable logging
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
# Logging to file
fh = logging.FileHandler(LOG_FILE)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
# Logging to console
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
ch.setFormatter(formatter)

logger.addHandler(fh)
logger.addHandler(ch)


class Bot:
    def __init__(self):

        self.updater = Updater(TOKEN)
        self.dsp = self.updater.dispatcher

        # register handler functions which define how the bot reacts to events
        self.dsp.add_handler(CommandHandler("start", get_help))
        self.dsp.add_handler(CommandHandler("help", get_help))
        self.dsp.add_handler(CommandHandler("sentiment", get_sentiment))
        self.dsp.add_handler(CommandHandler("answer", get_answer))
        self.dsp.add_handler(MessageHandler(Filters.text, echo))
        self.dsp.add_error_handler(error)

        logger.info('Im alive!')

    def power_on(self):
        # start the Bot
        self.updater.start_polling()
        self.updater.idle()

# define command handlers. These usually take the two arguments: bot and
# update. Error handlers also receive the raised TelegramError object in error.


def echo(bot, update):
    logger.info('echo recieved message: {}'.format(update.message.text))
    bot.sendMessage(update.message.chat_id, text=update.message.text)


def error(bot, update, error):
    # all uncaught telegram-related exceptions will be rerouted here
    logger.error('Update "%s" caused error "%s"' % (update, error))


def get_help(bot, update):
    logger.info('get_help recieved message: {}'.format(update.message.text))
    help_msg = ('Greetings, {} {}! Name is {}, at your service.\n'
                'I currently support the following commands:\n'
                '/start - begins our chat and prints this message\n'
                '/help - prints this message\n'
                '/sentiment [message] - predicts the sentiment of the message\n'
                '/answer [question] - answers the question').format(
        update.message.from_user.first_name, update.message.from_user.last_name, bot.name)
    bot.sendMessage(update.message.chat_id, text=help_msg)


def get_sentiment(bot, update):
    '''
    Now determine the sentiment of usr_msg.
    This should return a real number in [0,1].
    '''
    logger.info('get_sentiment recieved message: {}'.format(update.message.text))
    try:
        # get message text without the command '/sentiment'
        usr_msg = update.message.text.split(' ', maxsplit=1)[1]
        msg_sentiment = 0.5

        bot.sendMessage(update.message.chat_id, text=msg_sentiment)
    except IndexError:
        bot.sendMessage(update.message.chat_id, text='Write your message after the command')
    except Exception as e:
        logger.error(e)
        
def get_answer(bot, update):
    '''
    Now determine answer based on IR engine.
    This should return an answer from FAQ'
    '''
    logger.info('get_answer recieved message: {}'.format(update.message.text))
    try:
        # get message text without the command 
        usr_msg = update.message.text

        answer = engine.get_top(usr_msg, top_k=3)[0]
                        
        bot.sendMessage(update.message.chat_id, text=answer)
    except IndexError:
        bot.sendMessage(update.message.chat_id, text='Write your message after the command')
    except Exception as e:
        logger.error(e)

my_bot = Bot()
my_bot.power_on()
# Out:
# 2017-12-11 17:20:07,467 - __main__ - INFO - Im alive!
# 2017-12-11 17:20:19,773 - __main__ - INFO - get_answer recieved message: /answer Где можно заплатить по кредит
# 2017-12-11 17:20:47,452 - __main__ - INFO - get_answer recieved message: /answer Зачем мне вообще кредитная карта
# 2017-12-11 17:21:06,931 - __main__ - INFO - get_answer recieved message: /answer Какой тип счета выбирать в банкомате при снятии наличных
